# %% [markdown]
# # Cifar_10 이미지 분류_v1

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
seed = 2022
np.random.seed(seed)
tf.random.set_seed(seed)

# %% [markdown]
# - 데이터 전처리

# %%
from tensorflow.keras.datasets import cifar10
(X_train, y_train), (X_test, y_test) = cifar10.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 11s 0us/step
# 170508288/170498071 [==============================] - 11s 0us/step

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((50000, 32, 32, 3), (10000, 32, 32, 3), (50000, 1), (10000, 1))

# %%
class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer',
               'dog', 'frog', 'horse', 'ship', 'truck']

# %%
plt.figure(figsize=(8,2))
for i in range(10):
    plt.subplot(1,10,i+1)
    plt.imshow(X_train[i]), plt.axis('off')
    plt.title(class_names[y_train[i,0]], fontsize=8)
plt.show()

# %%
# X_data: scaling
X_train = X_train/255.
X_test = X_test/255.

# %%
# y_data: ont hot encoding
from tensorflow.keras.utils import to_categorical
Y_train = to_categorical(y_train)
Y_test = to_categorical(y_test)

# %% [markdown]
# - 모델 정의 / 설정 / 학습 / 평가

# %%
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Dense, Conv2D, Flatten, MaxPooling2D, Dropout
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.optimizers import RMSprop

# %%
model = Sequential([
    Conv2D(32, (3,3), input_shape=X_train.shape[1:], padding='same', activation='relu'),
    Conv2D(32, (3,3), activation='relu'),
    MaxPooling2D(),
    Dropout(0.25),
    Conv2D(64, (3,3), input_shape=X_train.shape[1:], padding='same', activation='relu'),
    Conv2D(64, (3,3), activation='relu'),
    MaxPooling2D(),
    Dropout(0.25),
    Flatten(),
    Dense(512, activation='relu'),
    Dropout(0.5),
    Dense(10, activation='softmax')   
])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 32, 32, 32)        896
#
#  conv2d_1 (Conv2D)           (None, 30, 30, 32)        9248
#
#  max_pooling2d (MaxPooling2D  (None, 15, 15, 32)       0
#  )
#
#  dropout (Dropout)           (None, 15, 15, 32)        0
#
#  conv2d_2 (Conv2D)           (None, 15, 15, 64)        18496
#
#  conv2d_3 (Conv2D)           (None, 13, 13, 64)        36928
#
#  max_pooling2d_1 (MaxPooling  (None, 6, 6, 64)         0
#  2D)
#
#  dropout_1 (Dropout)         (None, 6, 6, 64)          0
#
#  flatten (Flatten)           (None, 2304)              0
#
#  dense (Dense)               (None, 512)               1180160
#
#  dropout_2 (Dropout)         (None, 512)               0
#
#  dense_1 (Dense)             (None, 10)                5130
#
# =================================================================
# Total params: 1,250,858
# Trainable params: 1,250,858
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(
    optimizer=RMSprop(learning_rate=0.0001, decay=1e-6),
    loss='categorical_crossentropy', metrics=['accuracy']
)

# %%
model_path = 'best-cifar10-v1.h5'
mc = ModelCheckpoint(model_path, save_best_only=True, verbose=1)
es = EarlyStopping(patience=10)

# %%
hist = model.fit(
    X_train, Y_train, validation_split=0.2,
    epochs=100, batch_size=32, callbacks=[mc, es]
)
# Out:
# Epoch 1/100
# 1248/1250 [============================>.] - ETA: 0s - loss: 1.8287 - accuracy: 0.3279
# Epoch 1: val_loss improved from inf to 1.57335, saving model to best-cifar10-v1.h5
# 1250/1250 [==============================] - 21s 7ms/step - loss: 1.8286 - accuracy: 0.3280 - val_loss: 1.5734 - val_accuracy: 0.4263
# Epoch 2/100
# 1247/1250 [============================>.] - ETA: 0s - loss: 1.5207 - accuracy: 0.4433
# Epoch 2: val_loss improved from 1.57335 to 1.38004, saving model to best-cifar10-v1.h5
# 1250/1250 [==============================] - 7s 6ms/step - loss: 1.5205 - accuracy: 0.4436 - val_loss: 1.3800 - val_accuracy: 0.5026
# Epoch 3/100
# 1240/1250 [============================>.] - ETA: 0s - loss: 1.3946 - accuracy: 0.4946
# Epoch 3: val_loss improved from 1.38004 to 1.27130, saving model to best-cifar10-v1.h5
# 1250/1250 [==============================] - 7s 6ms/step - loss: 1.3939 - accuracy: 0.4950 - val_loss: 1.2713 - val_accuracy: 0.5543
# Epoch 4/100
# 1241/1250 [============================>.] - ETA: 0s - loss: 1.2980 - accuracy: 0.5359
# Epoch 4: val_loss improved from 1.27130 to 1.24165, saving model to best-cifar10-v1.h5
# 1250/1250 [==============================] - 7s 6ms/step - loss: 1.2977 - accuracy: 0.5361 - val_loss: 1.2416 - val_accuracy: 0.5514
# Epoch 5/100
# 1244/1250 [============================>.] - ETA: 0s - loss: 1.2178 - accuracy: 0.5655
# Epoch 5: val_loss improved from 1.24165 to 1.19841, saving model to best-cifar10-v1.h5
# 1250/1250 [==============================] - 7s 6ms/step - loss: 1.2176 - accuracy: 0.5656 - val_loss: 1.1984 - val_accuracy: 0.5822
# Epoch 6/100
# 1250/1250 [==============================] - ETA: 0s - loss: 1.1554 - accuracy: 0.5928
# Epoch 6: val_loss improved from 1.19841 to 1.05846, saving model to best-cifar10-v1.h5
# 1250/1250 [==============================] - 7s 6ms/step - loss: 1.1554 - accuracy: 0.5928 - val_loss: 1.0585 - val_accuracy: 0.6322
# Epoch 7/100
# 1244/1250 [============================>.] - ETA: 0s - loss: 1.1012 - accuracy: 0.6168
# Epoch 7: val_loss improved from 1.05846 to 1.05730, saving model to best-cifar10-v1.h5
# 1250/1250 [==============================] - 8s 6ms/step - loss: 1.1009 - accuracy: 0.6169 - val_loss: 1.0573 - val_accuracy: 0.6264
# Epoch 8/100
# 1240/1250 [============================>.] - ETA: 0s - loss: 1.0579 - accuracy: 0.6300
# Epoch 8: val_loss improved from 1.05730 to 0.98521, saving model to best-cifar10-v1.h5
# 1250/1250 [==============================] - 7s 6ms/step - loss: 1.0565 - accuracy: 0.6305 - val_loss: 0.9852 - val_accuracy: 0.6542
# Epoch 9/100
# 1247/1250 [============================>.] - ETA: 0s - loss: 1.0148 - accuracy: 0.6449
# Epoch 9: val_loss improved from 0.98521 to 0.97042, saving model to best-cifar10-v1.h5
# 1250/1250 [==============================] - 7s 6ms/step - loss: 1.0149 - accuracy: 0.6449 - val_loss: 0.9704 - val_accuracy: 0.6610
# Epoch 10/100
# 1247/1250 [============================>.] - ETA: 0s - loss: 0.9806 - accuracy: 0.6579
# Epoch 10: val_loss did not improve from 0.97042
# 1250/1250 [==============================] - 7s 6ms/step - loss: 0.9806 - accuracy: 0.6579 - val_loss: 0.9747 - val_accuracy: 0.6540
# Epoch 11/100
# 1244/1250 [============================>.] - ETA: 0s - loss: 0.9514 - accuracy: 0.6690
# Epoch 11: val_loss improved from 0.97042 to 0.88445, saving model to best-cifar10-v1.h5
# 1250/1250 [==============================] - 8s 6ms/step - loss: 0.9518 - accuracy: 0.6690 - val_loss: 0.8845 - val_accuracy: 0.6891
# Epoch 12/100
# 1242/1250 [============================>.] - ETA: 0s - loss: 0.9242 - accuracy: 0.6779
# Epoch 12: val_loss improved from 0.88445 to 0.87551, saving model to best-cifar10-v1.h5
# 1250/1250 [==============================] - 8s 6ms/step - loss: 0.9244 - accuracy: 0.6781 - val_loss: 0.8755 - val_accuracy: 0.6930
# Epoch 13/100
# 1244/1250 [============================>.] - ETA: 0s - loss: 0.8998 - accuracy: 0.6866
# Epoch 13: val_loss did not improve from 0.87551
# 1250/1250 [==============================] - 8s 6ms/step - loss: 0.8999 - accuracy: 0.6867 - val_loss: 0.8832 - val_accuracy: 0.6881
# Epoch 14/100
# 1247/1250 [============================>.] - ETA: 0s - loss: 0.8782 - accuracy: 0.6941
# Epoch 14: val_loss improved from 0.87551 to 0.82833, saving model to best-cifar10-v1.h5
# 1250/1250 [==============================] - 7s 6ms/step - loss: 0.8781 - accuracy: 0.6940 - val_loss: 0.8283 - val_accuracy: 0.7059
# Epoch 15/100
# 1248/1250 [============================>.] - ETA: 0s - loss: 0.8540 - accuracy: 0.7049
# Epoch 15: val_loss did not improve from 0.82833
# 1250/1250 [==============================] - 7s 6ms/step - loss: 0.8540 - accuracy: 0.7049 - val_loss: 0.8370 - val_accuracy: 0.7072
# Epoch 16/100
# 1242/1250 [============================>.] - ETA: 0s - loss: 0.8391 - accuracy: 0.7114
# Epoch 16: val_loss improved from 0.82833 to 0.81461, saving model to best-cifar10-v1.h5
# 1250/1250 [==============================] - 7s 6ms/step - loss: 0.8400 - accuracy: 0.7109 - val_loss: 0.8146 - val_accuracy: 0.7201
# Epoch 17/100
# 1245/1250 [============================>.] - ETA: 0s - loss: 0.8260 - accuracy: 0.7123
# Epoch 17: val_loss improved from 0.81461 to 0.78260, saving model to best-cifar10-v1.h5
# 1250/1250 [==============================] - 8s 6ms/step - loss: 0.8254 - accuracy: 0.7127 - val_loss: 0.7826 - val_accuracy: 0.7269
# Epoch 18/100
# 1247/1250 [============================>.] - ETA: 0s - loss: 0.8053 - accuracy: 0.7227
# Epoch 18: val_loss did not improve from 0.78260
# 1250/1250 [==============================] - 7s 6ms/step - loss: 0.8054 - accuracy: 0.7225 - val_loss: 0.7837 - val_accuracy: 0.7308
# Epoch 19/100
# 1244/1250 [============================>.] - ETA: 0s - loss: 0.7970 - accuracy: 0.7249
# Epoch 19: val_loss improved from 0.78260 to 0.77500, saving model to best-cifar10-v1.h5
# 1250/1250 [==============================] - 7s 6ms/step - loss: 0.7968 - accuracy: 0.7250 - val_loss: 0.7750 - val_accuracy: 0.7289
# Epoch 20/100
# 1250/1250 [==============================] - ETA: 0s - loss: 0.7843 - accuracy: 0.7308
# Epoch 20: val_loss improved from 0.77500 to 0.76703, saving model to best-cifar10-v1.h5
# 1250/1250 [==============================] - 7s 6ms/step - loss: 0.7843 - accuracy: 0.7308 - val_loss: 0.7670 - val_accuracy: 0.7369
# Epoch 21/100
# 1242/1250 [============================>.] - ETA: 0s - loss: 0.7735 - accuracy: 0.7318
# Epoch 21: val_loss improved from 0.76703 to 0.76153, saving model to best-cifar10-v1.h5
# 1250/1250 [==============================] - 8s 6ms/step - loss: 0.7731 - accuracy: 0.7320 - val_loss: 0.7615 - val_accuracy: 0.7380
# Epoch 22/100
# 1243/1250 [============================>.] - ETA: 0s - loss: 0.7659 - accuracy: 0.7360
# Epoch 22: val_loss did not improve from 0.76153
# 1250/1250 [==============================] - 7s 6ms/step - loss: 0.7655 - accuracy: 0.7362 - val_loss: 0.7652 - val_accuracy: 0.7396
# Epoch 23/100
# 1244/1250 [============================>.] - ETA: 0s - loss: 0.7564 - accuracy: 0.7398
# Epoch 23: val_loss improved from 0.76153 to 0.73893, saving model to best-cifar10-v1.h5
# 1250/1250 [==============================] - 7s 6ms/step - loss: 0.7568 - accuracy: 0.7397 - val_loss: 0.7389 - val_accuracy: 0.7469
# Epoch 24/100
# 1248/1250 [============================>.] - ETA: 0s - loss: 0.7416 - accuracy: 0.7459
# Epoch 24: val_loss improved from 0.73893 to 0.73181, saving model to best-cifar10-v1.h5
# 1250/1250 [==============================] - 8s 6ms/step - loss: 0.7414 - accuracy: 0.7460 - val_loss: 0.7318 - val_accuracy: 0.7496
# Epoch 25/100
# 1245/1250 [============================>.] - ETA: 0s - loss: 0.7400 - accuracy: 0.7473
# Epoch 25: val_loss improved from 0.73181 to 0.72548, saving model to best-cifar10-v1.h5
# 1250/1250 [==============================] - 8s 6ms/step - loss: 0.7399 - accuracy: 0.7474 - val_loss: 0.7255 - val_accuracy: 0.7473
# Epoch 26/100
# 1241/1250 [============================>.] - ETA: 0s - loss: 0.7305 - accuracy: 0.7495
# Epoch 26: val_loss improved from 0.72548 to 0.71280, saving model to best-cifar10-v1.h5
# 1250/1250 [==============================] - 7s 6ms/step - loss: 0.7305 - accuracy: 0.7494 - val_loss: 0.7128 - val_accuracy: 0.7569
# Epoch 27/100
# 1247/1250 [============================>.] - ETA: 0s - loss: 0.7262 - accuracy: 0.7521
# Epoch 27: val_loss improved from 0.71280 to 0.71215, saving model to best-cifar10-v1.h5
# 1250/1250 [==============================] - 7s 6ms/step - loss: 0.7263 - accuracy: 0.7521 - val_loss: 0.7121 - val_accuracy: 0.7588
# Epoch 28/100
# 1249/1250 [============================>.] - ETA: 0s - loss: 0.7187 - accuracy: 0.7551
# Epoch 28: val_loss improved from 0.71215 to 0.70981, saving model to best-cifar10-v1.h5
# 1250/1250 [==============================] - 7s 6ms/step - loss: 0.7186 - accuracy: 0.7551 - val_loss: 0.7098 - val_accuracy: 0.7531
# Epoch 29/100
# 1248/1250 [============================>.] - ETA: 0s - loss: 0.7164 - accuracy: 0.7546
# Epoch 29: val_loss improved from 0.70981 to 0.70218, saving model to best-cifar10-v1.h5
# 1250/1250 [==============================] - 8s 6ms/step - loss: 0.7161 - accuracy: 0.7546 - val_loss: 0.7022 - val_accuracy: 0.7592
# Epoch 30/100
# 1244/1250 [============================>.] - ETA: 0s - loss: 0.7113 - accuracy: 0.7584
# Epoch 30: val_loss did not improve from 0.70218
# 1250/1250 [==============================] - 7s 6ms/step - loss: 0.7118 - accuracy: 0.7584 - val_loss: 0.7041 - val_accuracy: 0.7594
# Epoch 31/100
# 1244/1250 [============================>.] - ETA: 0s - loss: 0.7041 - accuracy: 0.7598
# Epoch 31: val_loss did not improve from 0.70218
# 1250/1250 [==============================] - 8s 6ms/step - loss: 0.7042 - accuracy: 0.7598 - val_loss: 0.7075 - val_accuracy: 0.7582
# Epoch 32/100
# 1249/1250 [============================>.] - ETA: 0s - loss: 0.7046 - accuracy: 0.7594
# Epoch 32: val_loss did not improve from 0.70218
# 1250/1250 [==============================] - 8s 6ms/step - loss: 0.7044 - accuracy: 0.7595 - val_loss: 0.7341 - val_accuracy: 0.7506
# Epoch 33/100
# 1245/1250 [============================>.] - ETA: 0s - loss: 0.6968 - accuracy: 0.7635
# Epoch 33: val_loss improved from 0.70218 to 0.69215, saving model to best-cifar10-v1.h5
# 1250/1250 [==============================] - 8s 6ms/step - loss: 0.6963 - accuracy: 0.7637 - val_loss: 0.6921 - val_accuracy: 0.7659
# Epoch 34/100
# 1245/1250 [============================>.] - ETA: 0s - loss: 0.6898 - accuracy: 0.7652
# Epoch 34: val_loss did not improve from 0.69215
# 1250/1250 [==============================] - 8s 6ms/step - loss: 0.6894 - accuracy: 0.7655 - val_loss: 0.7203 - val_accuracy: 0.7568
# Epoch 35/100
# 1246/1250 [============================>.] - ETA: 0s - loss: 0.6874 - accuracy: 0.7680
# Epoch 35: val_loss did not improve from 0.69215
# 1250/1250 [==============================] - 8s 6ms/step - loss: 0.6869 - accuracy: 0.7682 - val_loss: 0.7228 - val_accuracy: 0.7545
# Epoch 36/100
# 1245/1250 [============================>.] - ETA: 0s - loss: 0.6891 - accuracy: 0.7675
# Epoch 36: val_loss did not improve from 0.69215
# 1250/1250 [==============================] - 8s 6ms/step - loss: 0.6894 - accuracy: 0.7674 - val_loss: 0.7154 - val_accuracy: 0.7584
# Epoch 37/100
# 1241/1250 [============================>.] - ETA: 0s - loss: 0.6873 - accuracy: 0.7645
# Epoch 37: val_loss improved from 0.69215 to 0.67936, saving model to best-cifar10-v1.h5
# 1250/1250 [==============================] - 8s 6ms/step - loss: 0.6874 - accuracy: 0.7643 - val_loss: 0.6794 - val_accuracy: 0.7688
# Epoch 38/100
# 1244/1250 [============================>.] - ETA: 0s - loss: 0.6803 - accuracy: 0.7712
# Epoch 38: val_loss did not improve from 0.67936
# 1250/1250 [==============================] - 7s 6ms/step - loss: 0.6803 - accuracy: 0.7713 - val_loss: 0.6823 - val_accuracy: 0.7674
# Epoch 39/100
# 1248/1250 [============================>.] - ETA: 0s - loss: 0.6732 - accuracy: 0.7730
# Epoch 39: val_loss did not improve from 0.67936
# 1250/1250 [==============================] - 7s 6ms/step - loss: 0.6735 - accuracy: 0.7729 - val_loss: 0.6805 - val_accuracy: 0.7684
# Epoch 40/100
# 1247/1250 [============================>.] - ETA: 0s - loss: 0.6726 - accuracy: 0.7737
# Epoch 40: val_loss did not improve from 0.67936
# 1250/1250 [==============================] - 8s 6ms/step - loss: 0.6724 - accuracy: 0.7738 - val_loss: 0.6846 - val_accuracy: 0.7682
# Epoch 41/100
# 1249/1250 [============================>.] - ETA: 0s - loss: 0.6671 - accuracy: 0.7743
# Epoch 41: val_loss did not improve from 0.67936
# 1250/1250 [==============================] - 7s 6ms/step - loss: 0.6671 - accuracy: 0.7743 - val_loss: 0.6911 - val_accuracy: 0.7620
# Epoch 42/100
# 1247/1250 [============================>.] - ETA: 0s - loss: 0.6703 - accuracy: 0.7762
# Epoch 42: val_loss did not improve from 0.67936
# 1250/1250 [==============================] - 7s 6ms/step - loss: 0.6709 - accuracy: 0.7761 - val_loss: 0.7043 - val_accuracy: 0.7633
# Epoch 43/100
# 1249/1250 [============================>.] - ETA: 0s - loss: 0.6590 - accuracy: 0.7789
# Epoch 43: val_loss improved from 0.67936 to 0.66651, saving model to best-cifar10-v1.h5
# 1250/1250 [==============================] - 8s 6ms/step - loss: 0.6590 - accuracy: 0.7789 - val_loss: 0.6665 - val_accuracy: 0.7745
# Epoch 44/100
# 1243/1250 [============================>.] - ETA: 0s - loss: 0.6599 - accuracy: 0.7786
# Epoch 44: val_loss did not improve from 0.66651
# 1250/1250 [==============================] - 7s 6ms/step - loss: 0.6606 - accuracy: 0.7786 - val_loss: 0.6700 - val_accuracy: 0.7757
# Epoch 45/100
# 1247/1250 [============================>.] - ETA: 0s - loss: 0.6575 - accuracy: 0.7790
# Epoch 45: val_loss did not improve from 0.66651
# 1250/1250 [==============================] - 8s 6ms/step - loss: 0.6582 - accuracy: 0.7787 - val_loss: 0.6810 - val_accuracy: 0.7769
# Epoch 46/100
# 1242/1250 [============================>.] - ETA: 0s - loss: 0.6537 - accuracy: 0.7812
# Epoch 46: val_loss did not improve from 0.66651
# 1250/1250 [==============================] - 8s 6ms/step - loss: 0.6547 - accuracy: 0.7809 - val_loss: 0.7039 - val_accuracy: 0.7679
# Epoch 47/100
# 1242/1250 [============================>.] - ETA: 0s - loss: 0.6511 - accuracy: 0.7828
# Epoch 47: val_loss improved from 0.66651 to 0.66014, saving model to best-cifar10-v1.h5
# 1250/1250 [==============================] - 7s 6ms/step - loss: 0.6514 - accuracy: 0.7826 - val_loss: 0.6601 - val_accuracy: 0.7742
# Epoch 48/100
# 1248/1250 [============================>.] - ETA: 0s - loss: 0.6440 - accuracy: 0.7817
# Epoch 48: val_loss did not improve from 0.66014
# 1250/1250 [==============================] - 7s 6ms/step - loss: 0.6439 - accuracy: 0.7818 - val_loss: 0.6687 - val_accuracy: 0.7733
# Epoch 49/100
# 1249/1250 [============================>.] - ETA: 0s - loss: 0.6459 - accuracy: 0.7842
# Epoch 49: val_loss did not improve from 0.66014
# 1250/1250 [==============================] - 8s 6ms/step - loss: 0.6461 - accuracy: 0.7842 - val_loss: 0.6604 - val_accuracy: 0.7737
# Epoch 50/100
# 1246/1250 [============================>.] - ETA: 0s - loss: 0.6397 - accuracy: 0.7846
# Epoch 50: val_loss did not improve from 0.66014
# 1250/1250 [==============================] - 8s 6ms/step - loss: 0.6394 - accuracy: 0.7847 - val_loss: 0.6773 - val_accuracy: 0.7737
# Epoch 51/100
# 1248/1250 [============================>.] - ETA: 0s - loss: 0.6343 - accuracy: 0.7863
# Epoch 51: val_loss improved from 0.66014 to 0.65468, saving model to best-cifar10-v1.h5
# 1250/1250 [==============================] - 8s 6ms/step - loss: 0.6344 - accuracy: 0.7862 - val_loss: 0.6547 - val_accuracy: 0.7779
# Epoch 52/100
# 1246/1250 [============================>.] - ETA: 0s - loss: 0.6362 - accuracy: 0.7878
# Epoch 52: val_loss did not improve from 0.65468
# 1250/1250 [==============================] - 7s 6ms/step - loss: 0.6364 - accuracy: 0.7877 - val_loss: 0.6612 - val_accuracy: 0.7798
# Epoch 53/100
# 1241/1250 [============================>.] - ETA: 0s - loss: 0.6325 - accuracy: 0.7851
# Epoch 53: val_loss did not improve from 0.65468
# 1250/1250 [==============================] - 7s 6ms/step - loss: 0.6330 - accuracy: 0.7850 - val_loss: 0.6671 - val_accuracy: 0.7760
# Epoch 54/100
# 1250/1250 [==============================] - ETA: 0s - loss: 0.6381 - accuracy: 0.7873
# Epoch 54: val_loss improved from 0.65468 to 0.64217, saving model to best-cifar10-v1.h5
# 1250/1250 [==============================] - 7s 6ms/step - loss: 0.6381 - accuracy: 0.7873 - val_loss: 0.6422 - val_accuracy: 0.7817
# Epoch 55/100
# 1247/1250 [============================>.] - ETA: 0s - loss: 0.6291 - accuracy: 0.7882
# Epoch 55: val_loss did not improve from 0.64217
# 1250/1250 [==============================] - 7s 6ms/step - loss: 0.6292 - accuracy: 0.7880 - val_loss: 0.6535 - val_accuracy: 0.7831
# Epoch 56/100
# 1243/1250 [============================>.] - ETA: 0s - loss: 0.6258 - accuracy: 0.7902
# Epoch 56: val_loss did not improve from 0.64217
# 1250/1250 [==============================] - 7s 6ms/step - loss: 0.6277 - accuracy: 0.7896 - val_loss: 0.6710 - val_accuracy: 0.7759
# Epoch 57/100
# 1245/1250 [============================>.] - ETA: 0s - loss: 0.6298 - accuracy: 0.7890
# Epoch 57: val_loss did not improve from 0.64217
# 1250/1250 [==============================] - 8s 6ms/step - loss: 0.6298 - accuracy: 0.7892 - val_loss: 0.6507 - val_accuracy: 0.7827
# Epoch 58/100
# 1245/1250 [============================>.] - ETA: 0s - loss: 0.6203 - accuracy: 0.7936
# Epoch 58: val_loss did not improve from 0.64217
# 1250/1250 [==============================] - 7s 6ms/step - loss: 0.6198 - accuracy: 0.7937 - val_loss: 0.6878 - val_accuracy: 0.7762
# Epoch 59/100
# 1246/1250 [============================>.] - ETA: 0s - loss: 0.6221 - accuracy: 0.7908
# Epoch 59: val_loss did not improve from 0.64217
# 1250/1250 [==============================] - 8s 6ms/step - loss: 0.6223 - accuracy: 0.7908 - val_loss: 0.6815 - val_accuracy: 0.7748
# Epoch 60/100
# 1246/1250 [============================>.] - ETA: 0s - loss: 0.6222 - accuracy: 0.7936
# Epoch 60: val_loss did not improve from 0.64217
# 1250/1250 [==============================] - 8s 6ms/step - loss: 0.6219 - accuracy: 0.7937 - val_loss: 0.6770 - val_accuracy: 0.7767
# Epoch 61/100
# 1245/1250 [============================>.] - ETA: 0s - loss: 0.6141 - accuracy: 0.7961
# Epoch 61: val_loss did not improve from 0.64217
# 1250/1250 [==============================] - 8s 6ms/step - loss: 0.6138 - accuracy: 0.7960 - val_loss: 0.6590 - val_accuracy: 0.7818
# Epoch 62/100
# 1243/1250 [============================>.] - ETA: 0s - loss: 0.6144 - accuracy: 0.7953
# Epoch 62: val_loss did not improve from 0.64217
# 1250/1250 [==============================] - 8s 6ms/step - loss: 0.6150 - accuracy: 0.7950 - val_loss: 0.6998 - val_accuracy: 0.7735
# Epoch 63/100
# 1249/1250 [============================>.] - ETA: 0s - loss: 0.6136 - accuracy: 0.7955
# Epoch 63: val_loss did not improve from 0.64217
# 1250/1250 [==============================] - 7s 6ms/step - loss: 0.6140 - accuracy: 0.7955 - val_loss: 0.6525 - val_accuracy: 0.7814
# Epoch 64/100
# 1249/1250 [============================>.] - ETA: 0s - loss: 0.6150 - accuracy: 0.7935
# Epoch 64: val_loss did not improve from 0.64217
# 1250/1250 [==============================] - 8s 6ms/step - loss: 0.6150 - accuracy: 0.7934 - val_loss: 0.6599 - val_accuracy: 0.7777

# %%
best_model = load_model(model_path)
best_model.evaluate(X_test, Y_test)
# Out:
# 313/313 [==============================] - 1s 4ms/step - loss: 0.6618 - accuracy: 0.7793
# [0.6618340015411377, 0.7792999744415283]

# %% [markdown]
# - 학습과정 시각화

# %%
y_acc = hist.history['accuracy']
y_vloss = hist.history['val_loss']
xs = np.arange(1, len(y_acc)+1)

# %%
plt.figure(figsize=(12,8))
plt.plot(xs, y_acc, label='train accuracy')
plt.plot(xs, y_vloss, label='validation loss')
plt.legend(), plt.grid(), plt.ylim(0,1.2)
plt.xlabel('Epoch')
plt.title('Cifar-10 CNN model v1')
plt.show()
