# %% [markdown]
# # Cifar_10 이미지 분류_v2
# - 데이터 부풀리기 적용

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
seed = 2022
np.random.seed(seed)
tf.random.set_seed(seed)

# %% [markdown]
# - 데이터 전처리

# %%
from tensorflow.keras.datasets import cifar10
(X_train, y_train), (X_test, y_test) = cifar10.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 13s 0us/step
# 170508288/170498071 [==============================] - 13s 0us/step

# %%
# X_data: scaling
X_train = X_train/255.
X_test = X_test/255.

# %%
# y_data: ont hot encoding
from tensorflow.keras.utils import to_categorical
Y_train = to_categorical(y_train)
Y_test = to_categorical(y_test)

# %% [markdown]
# - 모델 정의 / 설정

# %%
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Dense, Conv2D, Flatten, MaxPooling2D, Dropout
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.optimizers import RMSprop

# %%
model = Sequential([
    Conv2D(32, (3,3), input_shape=X_train.shape[1:], padding='same', activation='relu'),
    Conv2D(32, (3,3), activation='relu'),
    MaxPooling2D(),
    Dropout(0.25),
    Conv2D(64, (3,3), input_shape=X_train.shape[1:], padding='same', activation='relu'),
    Conv2D(64, (3,3), activation='relu'),
    MaxPooling2D(),
    Dropout(0.25),
    Flatten(),
    Dense(512, activation='relu'),
    Dropout(0.5),
    Dense(10, activation='softmax')   
])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 32, 32, 32)        896
#
#  conv2d_1 (Conv2D)           (None, 30, 30, 32)        9248
#
#  max_pooling2d (MaxPooling2D  (None, 15, 15, 32)       0
#  )
#
#  dropout (Dropout)           (None, 15, 15, 32)        0
#
#  conv2d_2 (Conv2D)           (None, 15, 15, 64)        18496
#
#  conv2d_3 (Conv2D)           (None, 13, 13, 64)        36928
#
#  max_pooling2d_1 (MaxPooling  (None, 6, 6, 64)         0
#  2D)
#
#  dropout_1 (Dropout)         (None, 6, 6, 64)          0
#
#  flatten (Flatten)           (None, 2304)              0
#
#  dense (Dense)               (None, 512)               1180160
#
#  dropout_2 (Dropout)         (None, 512)               0
#
#  dense_1 (Dense)             (None, 10)                5130
#
# =================================================================
# Total params: 1,250,858
# Trainable params: 1,250,858
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(
    optimizer=RMSprop(learning_rate=0.0001, decay=1e-6),
    loss='categorical_crossentropy', metrics=['accuracy']
)

# %%
model_path = 'best-cifar10-v2.h5'
mc = ModelCheckpoint(model_path, save_best_only=True, verbose=1)
es = EarlyStopping(patience=10)

# %% [markdown]
# - 데이터 부풀리기

# %%
# 데이터 부풀리기 --> train 데이터만 부풀려야 하기에 validation을 미리 떼어놓는 작업
from sklearn.model_selection import train_test_split
X_train, X_valid, Y_train, Y_valid = train_test_split(
    X_train, Y_train, stratify=Y_train, test_size=0.2, random_state=seed
)

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

datagen = ImageDataGenerator(
    rotation_range=10,          # randomly rotate images in the range 15 degree
    width_shift_range=0.1,      # randomly shift images horizontally 
    height_shift_range=0.1,     # randomly shift images vertically
    shear_range=0.1,            # 도형의 기울기
    zoom_range=[0.8,1.5],       # 0.8~1.5 배 크기로 임의로 확대/축소
    horizontal_flip=True,       # randomly flip images
    vertical_flip=False,        # randomly flip images
    fill_mode='nearest'         # set mode for filling points outside the input boundaries
)

# %%
datagen.fit(X_train)

# %% [markdown]
# - 데이터 부풀리기 한 결과로 학습

# %%
hist = model.fit(
    datagen.flow(X_train, Y_train, batch_size=32),
    validation_data=(X_valid, Y_valid),
    epochs=100, callbacks=[mc, es]
)
# Out:
# Epoch 1/100
# 1248/1250 [============================>.] - ETA: 0s - loss: 1.8987 - accuracy: 0.3017
# Epoch 1: val_loss improved from inf to 1.62766, saving model to best-cifar10-v2.h5
# 1250/1250 [==============================] - 37s 20ms/step - loss: 1.8985 - accuracy: 0.3016 - val_loss: 1.6277 - val_accuracy: 0.4166
# Epoch 2/100
# 1249/1250 [============================>.] - ETA: 0s - loss: 1.6538 - accuracy: 0.3977
# Epoch 2: val_loss improved from 1.62766 to 1.46625, saving model to best-cifar10-v2.h5
# 1250/1250 [==============================] - 24s 19ms/step - loss: 1.6539 - accuracy: 0.3977 - val_loss: 1.4662 - val_accuracy: 0.4708
# Epoch 3/100
# 1248/1250 [============================>.] - ETA: 0s - loss: 1.5564 - accuracy: 0.4361
# Epoch 3: val_loss improved from 1.46625 to 1.40627, saving model to best-cifar10-v2.h5
# 1250/1250 [==============================] - 25s 20ms/step - loss: 1.5564 - accuracy: 0.4362 - val_loss: 1.4063 - val_accuracy: 0.4918
# Epoch 4/100
# 1249/1250 [============================>.] - ETA: 0s - loss: 1.4830 - accuracy: 0.4648
# Epoch 4: val_loss improved from 1.40627 to 1.32235, saving model to best-cifar10-v2.h5
# 1250/1250 [==============================] - 24s 19ms/step - loss: 1.4833 - accuracy: 0.4648 - val_loss: 1.3223 - val_accuracy: 0.5248
# Epoch 5/100
# 1249/1250 [============================>.] - ETA: 0s - loss: 1.4335 - accuracy: 0.4856
# Epoch 5: val_loss improved from 1.32235 to 1.28182, saving model to best-cifar10-v2.h5
# 1250/1250 [==============================] - 24s 20ms/step - loss: 1.4334 - accuracy: 0.4856 - val_loss: 1.2818 - val_accuracy: 0.5395
# Epoch 6/100
# 1248/1250 [============================>.] - ETA: 0s - loss: 1.3781 - accuracy: 0.5082
# Epoch 6: val_loss improved from 1.28182 to 1.24063, saving model to best-cifar10-v2.h5
# 1250/1250 [==============================] - 24s 20ms/step - loss: 1.3780 - accuracy: 0.5082 - val_loss: 1.2406 - val_accuracy: 0.5588
# Epoch 7/100
# 1248/1250 [============================>.] - ETA: 0s - loss: 1.3312 - accuracy: 0.5269
# Epoch 7: val_loss improved from 1.24063 to 1.20804, saving model to best-cifar10-v2.h5
# 1250/1250 [==============================] - 24s 19ms/step - loss: 1.3311 - accuracy: 0.5268 - val_loss: 1.2080 - val_accuracy: 0.5705
# Epoch 8/100
# 1248/1250 [============================>.] - ETA: 0s - loss: 1.2954 - accuracy: 0.5401
# Epoch 8: val_loss improved from 1.20804 to 1.15697, saving model to best-cifar10-v2.h5
# 1250/1250 [==============================] - 25s 20ms/step - loss: 1.2955 - accuracy: 0.5401 - val_loss: 1.1570 - val_accuracy: 0.5846
# Epoch 9/100
# 1248/1250 [============================>.] - ETA: 0s - loss: 1.2605 - accuracy: 0.5545
# Epoch 9: val_loss did not improve from 1.15697
# 1250/1250 [==============================] - 24s 19ms/step - loss: 1.2607 - accuracy: 0.5545 - val_loss: 1.2099 - val_accuracy: 0.5659
# Epoch 10/100
# 1249/1250 [============================>.] - ETA: 0s - loss: 1.2373 - accuracy: 0.5633
# Epoch 10: val_loss improved from 1.15697 to 1.12995, saving model to best-cifar10-v2.h5
# 1250/1250 [==============================] - 25s 20ms/step - loss: 1.2373 - accuracy: 0.5632 - val_loss: 1.1299 - val_accuracy: 0.6000
# Epoch 11/100
# 1249/1250 [============================>.] - ETA: 0s - loss: 1.2101 - accuracy: 0.5704
# Epoch 11: val_loss did not improve from 1.12995
# 1250/1250 [==============================] - 25s 20ms/step - loss: 1.2100 - accuracy: 0.5705 - val_loss: 1.1424 - val_accuracy: 0.5917
# Epoch 12/100
# 1249/1250 [============================>.] - ETA: 0s - loss: 1.1779 - accuracy: 0.5804
# Epoch 12: val_loss improved from 1.12995 to 1.07076, saving model to best-cifar10-v2.h5
# 1250/1250 [==============================] - 25s 20ms/step - loss: 1.1777 - accuracy: 0.5804 - val_loss: 1.0708 - val_accuracy: 0.6177
# Epoch 13/100
# 1250/1250 [==============================] - ETA: 0s - loss: 1.1635 - accuracy: 0.5915
# Epoch 13: val_loss improved from 1.07076 to 1.04424, saving model to best-cifar10-v2.h5
# 1250/1250 [==============================] - 25s 20ms/step - loss: 1.1635 - accuracy: 0.5915 - val_loss: 1.0442 - val_accuracy: 0.6257
# Epoch 14/100
# 1249/1250 [============================>.] - ETA: 0s - loss: 1.1408 - accuracy: 0.5977
# Epoch 14: val_loss improved from 1.04424 to 1.03268, saving model to best-cifar10-v2.h5
# 1250/1250 [==============================] - 25s 20ms/step - loss: 1.1405 - accuracy: 0.5978 - val_loss: 1.0327 - val_accuracy: 0.6378
# Epoch 15/100
# 1250/1250 [==============================] - ETA: 0s - loss: 1.1240 - accuracy: 0.6035
# Epoch 15: val_loss did not improve from 1.03268
# 1250/1250 [==============================] - 25s 20ms/step - loss: 1.1240 - accuracy: 0.6035 - val_loss: 1.0502 - val_accuracy: 0.6395
# Epoch 16/100
# 1249/1250 [============================>.] - ETA: 0s - loss: 1.1082 - accuracy: 0.6101
# Epoch 16: val_loss improved from 1.03268 to 0.96552, saving model to best-cifar10-v2.h5
# 1250/1250 [==============================] - 25s 20ms/step - loss: 1.1079 - accuracy: 0.6102 - val_loss: 0.9655 - val_accuracy: 0.6557
# Epoch 17/100
# 1249/1250 [============================>.] - ETA: 0s - loss: 1.0960 - accuracy: 0.6120
# Epoch 17: val_loss improved from 0.96552 to 0.95316, saving model to best-cifar10-v2.h5
# 1250/1250 [==============================] - 25s 20ms/step - loss: 1.0958 - accuracy: 0.6120 - val_loss: 0.9532 - val_accuracy: 0.6611
# Epoch 18/100
# 1249/1250 [============================>.] - ETA: 0s - loss: 1.0833 - accuracy: 0.6212
# Epoch 18: val_loss improved from 0.95316 to 0.94435, saving model to best-cifar10-v2.h5
# 1250/1250 [==============================] - 25s 20ms/step - loss: 1.0831 - accuracy: 0.6212 - val_loss: 0.9443 - val_accuracy: 0.6734
# Epoch 19/100
# 1250/1250 [==============================] - ETA: 0s - loss: 1.0649 - accuracy: 0.6290
# Epoch 19: val_loss improved from 0.94435 to 0.90987, saving model to best-cifar10-v2.h5
# 1250/1250 [==============================] - 25s 20ms/step - loss: 1.0649 - accuracy: 0.6290 - val_loss: 0.9099 - val_accuracy: 0.6817
# Epoch 20/100
# 1250/1250 [==============================] - ETA: 0s - loss: 1.0476 - accuracy: 0.6326
# Epoch 20: val_loss did not improve from 0.90987
# 1250/1250 [==============================] - 25s 20ms/step - loss: 1.0476 - accuracy: 0.6326 - val_loss: 0.9702 - val_accuracy: 0.6621
# Epoch 21/100
# 1249/1250 [============================>.] - ETA: 0s - loss: 1.0416 - accuracy: 0.6347
# Epoch 21: val_loss did not improve from 0.90987
# 1250/1250 [==============================] - 24s 20ms/step - loss: 1.0417 - accuracy: 0.6346 - val_loss: 0.9722 - val_accuracy: 0.6608
# Epoch 22/100
# 1250/1250 [==============================] - ETA: 0s - loss: 1.0260 - accuracy: 0.6377
# Epoch 22: val_loss did not improve from 0.90987
# 1250/1250 [==============================] - 25s 20ms/step - loss: 1.0260 - accuracy: 0.6377 - val_loss: 0.9488 - val_accuracy: 0.6762
# Epoch 23/100
# 1250/1250 [==============================] - ETA: 0s - loss: 1.0201 - accuracy: 0.6432
# Epoch 23: val_loss improved from 0.90987 to 0.89608, saving model to best-cifar10-v2.h5
# 1250/1250 [==============================] - 27s 21ms/step - loss: 1.0201 - accuracy: 0.6432 - val_loss: 0.8961 - val_accuracy: 0.6884
# Epoch 24/100
# 1249/1250 [============================>.] - ETA: 0s - loss: 1.0175 - accuracy: 0.6434
# Epoch 24: val_loss did not improve from 0.89608
# 1250/1250 [==============================] - 25s 20ms/step - loss: 1.0175 - accuracy: 0.6435 - val_loss: 0.8980 - val_accuracy: 0.6852
# Epoch 25/100
# 1249/1250 [============================>.] - ETA: 0s - loss: 1.0025 - accuracy: 0.6504
# Epoch 25: val_loss improved from 0.89608 to 0.87346, saving model to best-cifar10-v2.h5
# 1250/1250 [==============================] - 25s 20ms/step - loss: 1.0029 - accuracy: 0.6503 - val_loss: 0.8735 - val_accuracy: 0.7017
# Epoch 26/100
# 1248/1250 [============================>.] - ETA: 0s - loss: 0.9989 - accuracy: 0.6521
# Epoch 26: val_loss improved from 0.87346 to 0.83305, saving model to best-cifar10-v2.h5
# 1250/1250 [==============================] - 25s 20ms/step - loss: 0.9993 - accuracy: 0.6520 - val_loss: 0.8331 - val_accuracy: 0.7121
# Epoch 27/100
# 1249/1250 [============================>.] - ETA: 0s - loss: 0.9891 - accuracy: 0.6552
# Epoch 27: val_loss did not improve from 0.83305
# 1250/1250 [==============================] - 25s 20ms/step - loss: 0.9892 - accuracy: 0.6553 - val_loss: 0.8558 - val_accuracy: 0.6980
# Epoch 28/100
# 1250/1250 [==============================] - ETA: 0s - loss: 0.9768 - accuracy: 0.6608
# Epoch 28: val_loss did not improve from 0.83305
# 1250/1250 [==============================] - 24s 20ms/step - loss: 0.9768 - accuracy: 0.6608 - val_loss: 0.8412 - val_accuracy: 0.7083
# Epoch 29/100
# 1249/1250 [============================>.] - ETA: 0s - loss: 0.9765 - accuracy: 0.6578
# Epoch 29: val_loss did not improve from 0.83305
# 1250/1250 [==============================] - 24s 19ms/step - loss: 0.9764 - accuracy: 0.6579 - val_loss: 0.8952 - val_accuracy: 0.6900
# Epoch 30/100
# 1249/1250 [============================>.] - ETA: 0s - loss: 0.9641 - accuracy: 0.6667
# Epoch 30: val_loss did not improve from 0.83305
# 1250/1250 [==============================] - 24s 19ms/step - loss: 0.9640 - accuracy: 0.6668 - val_loss: 0.8868 - val_accuracy: 0.6940
# Epoch 31/100
# 1248/1250 [============================>.] - ETA: 0s - loss: 0.9579 - accuracy: 0.6670
# Epoch 31: val_loss did not improve from 0.83305
# 1250/1250 [==============================] - 24s 19ms/step - loss: 0.9580 - accuracy: 0.6669 - val_loss: 0.8821 - val_accuracy: 0.6998
# Epoch 32/100
# 1247/1250 [============================>.] - ETA: 0s - loss: 0.9596 - accuracy: 0.6655
# Epoch 32: val_loss improved from 0.83305 to 0.82989, saving model to best-cifar10-v2.h5
# 1250/1250 [==============================] - 25s 20ms/step - loss: 0.9597 - accuracy: 0.6655 - val_loss: 0.8299 - val_accuracy: 0.7136
# Epoch 33/100
# 1250/1250 [==============================] - ETA: 0s - loss: 0.9472 - accuracy: 0.6714
# Epoch 33: val_loss did not improve from 0.82989
# 1250/1250 [==============================] - 24s 20ms/step - loss: 0.9472 - accuracy: 0.6714 - val_loss: 0.8426 - val_accuracy: 0.7128
# Epoch 34/100
# 1248/1250 [============================>.] - ETA: 0s - loss: 0.9502 - accuracy: 0.6710
# Epoch 34: val_loss improved from 0.82989 to 0.81862, saving model to best-cifar10-v2.h5
# 1250/1250 [==============================] - 25s 20ms/step - loss: 0.9504 - accuracy: 0.6710 - val_loss: 0.8186 - val_accuracy: 0.7170
# Epoch 35/100
# 1250/1250 [==============================] - ETA: 0s - loss: 0.9490 - accuracy: 0.6748
# Epoch 35: val_loss improved from 0.81862 to 0.81500, saving model to best-cifar10-v2.h5
# 1250/1250 [==============================] - 25s 20ms/step - loss: 0.9490 - accuracy: 0.6748 - val_loss: 0.8150 - val_accuracy: 0.7202
# Epoch 36/100
# 1249/1250 [============================>.] - ETA: 0s - loss: 0.9403 - accuracy: 0.6758
# Epoch 36: val_loss did not improve from 0.81500
# 1250/1250 [==============================] - 24s 19ms/step - loss: 0.9406 - accuracy: 0.6757 - val_loss: 0.8421 - val_accuracy: 0.7082
# Epoch 37/100
# 1249/1250 [============================>.] - ETA: 0s - loss: 0.9374 - accuracy: 0.6767
# Epoch 37: val_loss did not improve from 0.81500
# 1250/1250 [==============================] - 25s 20ms/step - loss: 0.9374 - accuracy: 0.6767 - val_loss: 0.8173 - val_accuracy: 0.7192
# Epoch 38/100
# 1248/1250 [============================>.] - ETA: 0s - loss: 0.9280 - accuracy: 0.6779
# Epoch 38: val_loss did not improve from 0.81500
# 1250/1250 [==============================] - 25s 20ms/step - loss: 0.9284 - accuracy: 0.6778 - val_loss: 0.8453 - val_accuracy: 0.7105
# Epoch 39/100
# 1249/1250 [============================>.] - ETA: 0s - loss: 0.9288 - accuracy: 0.6783
# Epoch 39: val_loss improved from 0.81500 to 0.77129, saving model to best-cifar10-v2.h5
# 1250/1250 [==============================] - 24s 19ms/step - loss: 0.9287 - accuracy: 0.6783 - val_loss: 0.7713 - val_accuracy: 0.7332
# Epoch 40/100
# 1250/1250 [==============================] - ETA: 0s - loss: 0.9233 - accuracy: 0.6829
# Epoch 40: val_loss did not improve from 0.77129
# 1250/1250 [==============================] - 24s 19ms/step - loss: 0.9233 - accuracy: 0.6829 - val_loss: 0.8296 - val_accuracy: 0.7145
# Epoch 41/100
# 1249/1250 [============================>.] - ETA: 0s - loss: 0.9207 - accuracy: 0.6804
# Epoch 41: val_loss did not improve from 0.77129
# 1250/1250 [==============================] - 25s 20ms/step - loss: 0.9207 - accuracy: 0.6804 - val_loss: 0.8246 - val_accuracy: 0.7188
# Epoch 42/100
# 1250/1250 [==============================] - ETA: 0s - loss: 0.9161 - accuracy: 0.6858
# Epoch 42: val_loss improved from 0.77129 to 0.74509, saving model to best-cifar10-v2.h5
# 1250/1250 [==============================] - 25s 20ms/step - loss: 0.9161 - accuracy: 0.6858 - val_loss: 0.7451 - val_accuracy: 0.7415
# Epoch 43/100
# 1248/1250 [============================>.] - ETA: 0s - loss: 0.9122 - accuracy: 0.6853
# Epoch 43: val_loss did not improve from 0.74509
# 1250/1250 [==============================] - 24s 19ms/step - loss: 0.9126 - accuracy: 0.6851 - val_loss: 0.7730 - val_accuracy: 0.7321
# Epoch 44/100
# 1248/1250 [============================>.] - ETA: 0s - loss: 0.9106 - accuracy: 0.6869
# Epoch 44: val_loss did not improve from 0.74509
# 1250/1250 [==============================] - 24s 19ms/step - loss: 0.9110 - accuracy: 0.6867 - val_loss: 0.7724 - val_accuracy: 0.7318
# Epoch 45/100
# 1248/1250 [============================>.] - ETA: 0s - loss: 0.9114 - accuracy: 0.6838
# Epoch 45: val_loss did not improve from 0.74509
# 1250/1250 [==============================] - 24s 19ms/step - loss: 0.9112 - accuracy: 0.6839 - val_loss: 0.7658 - val_accuracy: 0.7381
# Epoch 46/100
# 1250/1250 [==============================] - ETA: 0s - loss: 0.9122 - accuracy: 0.6870
# Epoch 46: val_loss did not improve from 0.74509
# 1250/1250 [==============================] - 24s 20ms/step - loss: 0.9122 - accuracy: 0.6870 - val_loss: 0.8230 - val_accuracy: 0.7167
# Epoch 47/100
# 1249/1250 [============================>.] - ETA: 0s - loss: 0.9068 - accuracy: 0.6888
# Epoch 47: val_loss did not improve from 0.74509
# 1250/1250 [==============================] - 24s 19ms/step - loss: 0.9068 - accuracy: 0.6888 - val_loss: 0.7985 - val_accuracy: 0.7269
# Epoch 48/100
# 1250/1250 [==============================] - ETA: 0s - loss: 0.8975 - accuracy: 0.6912
# Epoch 48: val_loss did not improve from 0.74509
# 1250/1250 [==============================] - 24s 20ms/step - loss: 0.8975 - accuracy: 0.6912 - val_loss: 0.7714 - val_accuracy: 0.7344
# Epoch 49/100
# 1249/1250 [============================>.] - ETA: 0s - loss: 0.9026 - accuracy: 0.6926
# Epoch 49: val_loss did not improve from 0.74509
# 1250/1250 [==============================] - 25s 20ms/step - loss: 0.9026 - accuracy: 0.6926 - val_loss: 0.7960 - val_accuracy: 0.7309
# Epoch 50/100
# 1249/1250 [============================>.] - ETA: 0s - loss: 0.9010 - accuracy: 0.6923
# Epoch 50: val_loss did not improve from 0.74509
# 1250/1250 [==============================] - 24s 19ms/step - loss: 0.9010 - accuracy: 0.6923 - val_loss: 0.8076 - val_accuracy: 0.7284
# Epoch 51/100
# 1250/1250 [==============================] - ETA: 0s - loss: 0.8964 - accuracy: 0.6914
# Epoch 51: val_loss did not improve from 0.74509
# 1250/1250 [==============================] - 25s 20ms/step - loss: 0.8964 - accuracy: 0.6914 - val_loss: 0.7508 - val_accuracy: 0.7444
# Epoch 52/100
# 1248/1250 [============================>.] - ETA: 0s - loss: 0.8904 - accuracy: 0.6948
# Epoch 52: val_loss did not improve from 0.74509
# 1250/1250 [==============================] - 25s 20ms/step - loss: 0.8906 - accuracy: 0.6947 - val_loss: 0.8263 - val_accuracy: 0.7253

# %%
best_model = load_model(model_path)
best_model.evaluate(X_test, Y_test)
# Out:
# 313/313 [==============================] - 1s 4ms/step - loss: 0.7593 - accuracy: 0.7380
# [0.7592661380767822, 0.7379999756813049]

# %% [markdown]
# - 학습과정 시각화

# %%
y_acc = hist.history['accuracy']
y_vloss = hist.history['val_loss']
xs = np.arange(1, len(y_acc)+1)

# %%
plt.figure(figsize=(12,8))
plt.plot(xs, y_acc, label='train accuracy')
plt.plot(xs, y_vloss, label='validation loss')
plt.legend(), plt.grid(), plt.ylim(0,1.2)
plt.xlabel('Epoch')
plt.title('Cifar-10 CNN model v2')
plt.show()
