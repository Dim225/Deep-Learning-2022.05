# %% [markdown]
# # MNIST 손글씨 - CNN v1
# - 2 x Conv2D layers
# - 1 FCN layer
# - 1 Output layer

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
seed = 2022
np.random.seed(seed)
tf.random.set_seed(seed)

# %% [markdown]
# - 데이터 전처리

# %%
from tensorflow.keras.datasets import mnist
(X_train, y_train), (X_test, y_test) = mnist.load_data()
X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step
# 11501568/11490434 [==============================] - 0s 0us/step
# ((60000, 28, 28), (60000,), (10000, 28, 28), (10000,))

# %%
# X_train, X_test 정규화(0 ~ 1), 이미지 차원 변경: 2차원 --> 3차원
X_train = X_train.reshape(-1, 28, 28, 1) / 255.
X_test = X_test.reshape(-1, 28, 28, 1) / 255.
X_train.shape, X_test.shape
# Out:
# ((60000, 28, 28, 1), (10000, 28, 28, 1))

# %%
# One hot encoding
from tensorflow.keras.utils import to_categorical
Y_train = to_categorical(y_train)
Y_test = to_categorical(y_test)
Y_train.shape, Y_test.shape
# Out:
# ((60000, 10), (10000, 10))

# %% [markdown]
# - 모델 정의 / 설정 / 학습 / 평가

# %%
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Dense, Conv2D, Flatten
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

# %%
model = Sequential([
    Conv2D(32, kernel_size=(3,3), input_shape=(28,28,1), activation='relu'),
    Conv2D(64, (3,3), activation='relu'),
    Flatten(),
    Dense(512, activation='relu'),
    Dense(10, activation='softmax')
])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 26, 26, 32)        320
#
#  conv2d_1 (Conv2D)           (None, 24, 24, 64)        18496
#
#  flatten (Flatten)           (None, 36864)             0
#
#  dense (Dense)               (None, 512)               18874880
#
#  dense_1 (Dense)             (None, 10)                5130
#
# =================================================================
# Total params: 18,898,826
# Trainable params: 18,898,826
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile('adam', 'categorical_crossentropy', ['accuracy'])

# %%
model_path = 'best-mnist-cnn-v1.h5'
mc = ModelCheckpoint(model_path, save_best_only=True, verbose=1)
es = EarlyStopping(patience=10)

# %%
hist = model.fit(
    X_train, Y_train, validation_split=0.2, epochs=100, batch_size=200,
    callbacks=[mc, es]
)
# Out:
# Epoch 1/100
# 239/240 [============================>.] - ETA: 0s - loss: 0.1525 - accuracy: 0.9528
# Epoch 1: val_loss improved from inf to 0.05656, saving model to best-mnist-cnn-v1.h5
# 240/240 [==============================] - 16s 24ms/step - loss: 0.1521 - accuracy: 0.9529 - val_loss: 0.0566 - val_accuracy: 0.9831
# Epoch 2/100
# 238/240 [============================>.] - ETA: 0s - loss: 0.0356 - accuracy: 0.9892
# Epoch 2: val_loss improved from 0.05656 to 0.05326, saving model to best-mnist-cnn-v1.h5
# 240/240 [==============================] - 5s 22ms/step - loss: 0.0355 - accuracy: 0.9893 - val_loss: 0.0533 - val_accuracy: 0.9860
# Epoch 3/100
# 238/240 [============================>.] - ETA: 0s - loss: 0.0179 - accuracy: 0.9944
# Epoch 3: val_loss improved from 0.05326 to 0.04570, saving model to best-mnist-cnn-v1.h5
# 240/240 [==============================] - 5s 23ms/step - loss: 0.0178 - accuracy: 0.9945 - val_loss: 0.0457 - val_accuracy: 0.9879
# Epoch 4/100
# 238/240 [============================>.] - ETA: 0s - loss: 0.0111 - accuracy: 0.9964
# Epoch 4: val_loss did not improve from 0.04570
# 240/240 [==============================] - 5s 20ms/step - loss: 0.0110 - accuracy: 0.9964 - val_loss: 0.0514 - val_accuracy: 0.9868
# Epoch 5/100
# 238/240 [============================>.] - ETA: 0s - loss: 0.0070 - accuracy: 0.9977
# Epoch 5: val_loss did not improve from 0.04570
# 240/240 [==============================] - 5s 20ms/step - loss: 0.0070 - accuracy: 0.9977 - val_loss: 0.0614 - val_accuracy: 0.9858
# Epoch 6/100
# 238/240 [============================>.] - ETA: 0s - loss: 0.0071 - accuracy: 0.9975
# Epoch 6: val_loss did not improve from 0.04570
# 240/240 [==============================] - 5s 20ms/step - loss: 0.0071 - accuracy: 0.9975 - val_loss: 0.0472 - val_accuracy: 0.9871
# Epoch 7/100
# 238/240 [============================>.] - ETA: 0s - loss: 0.0030 - accuracy: 0.9992
# Epoch 7: val_loss did not improve from 0.04570
# 240/240 [==============================] - 5s 21ms/step - loss: 0.0031 - accuracy: 0.9992 - val_loss: 0.0520 - val_accuracy: 0.9887
# Epoch 8/100
# 238/240 [============================>.] - ETA: 0s - loss: 0.0019 - accuracy: 0.9994
# Epoch 8: val_loss did not improve from 0.04570
# 240/240 [==============================] - 5s 20ms/step - loss: 0.0019 - accuracy: 0.9994 - val_loss: 0.0532 - val_accuracy: 0.9896
# Epoch 9/100
# 238/240 [============================>.] - ETA: 0s - loss: 0.0057 - accuracy: 0.9985
# Epoch 9: val_loss did not improve from 0.04570
# 240/240 [==============================] - 5s 21ms/step - loss: 0.0057 - accuracy: 0.9985 - val_loss: 0.0582 - val_accuracy: 0.9887
# Epoch 10/100
# 238/240 [============================>.] - ETA: 0s - loss: 0.0050 - accuracy: 0.9982
# Epoch 10: val_loss did not improve from 0.04570
# 240/240 [==============================] - 5s 21ms/step - loss: 0.0049 - accuracy: 0.9982 - val_loss: 0.0588 - val_accuracy: 0.9876
# Epoch 11/100
# 238/240 [============================>.] - ETA: 0s - loss: 0.0029 - accuracy: 0.9991
# Epoch 11: val_loss did not improve from 0.04570
# 240/240 [==============================] - 5s 21ms/step - loss: 0.0031 - accuracy: 0.9990 - val_loss: 0.0588 - val_accuracy: 0.9878
# Epoch 12/100
# 238/240 [============================>.] - ETA: 0s - loss: 0.0041 - accuracy: 0.9987
# Epoch 12: val_loss did not improve from 0.04570
# 240/240 [==============================] - 5s 20ms/step - loss: 0.0041 - accuracy: 0.9987 - val_loss: 0.0546 - val_accuracy: 0.9890
# Epoch 13/100
# 238/240 [============================>.] - ETA: 0s - loss: 0.0022 - accuracy: 0.9994
# Epoch 13: val_loss did not improve from 0.04570
# 240/240 [==============================] - 5s 21ms/step - loss: 0.0022 - accuracy: 0.9994 - val_loss: 0.0604 - val_accuracy: 0.9894

# %%
best_model = load_model(model_path)
best_model.evaluate(X_test, Y_test)
# Out:
# 313/313 [==============================] - 1s 4ms/step - loss: 0.0412 - accuracy: 0.9878
# [0.04121852293610573, 0.9878000020980835]

# %% [markdown]
# - 학습과정 시각화

# %%
y_acc = hist.history['accuracy']
y_vloss = hist.history['val_loss']
xs = np.arange(1, len(y_acc)+1)

# %%
plt.figure(figsize=(12,8))
plt.plot(xs, y_acc, label='train accuracy')
plt.plot(xs, y_vloss, label='validation loss')
plt.legend(), plt.grid(), plt.ylim([0,1.2])
plt.xlabel('Epoch')
plt.title('MNIST CNN model v1')
plt.show()
