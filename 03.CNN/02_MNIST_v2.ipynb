# %% [markdown]
# # MNIST 손글씨 - CNN v2
# - 2 x Conv2D layers
# - MaxPooling 2D layer
# - 1 FCN layer
# - 1 Output layer

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
seed = 2022
np.random.seed(seed)
tf.random.set_seed(seed)

# %% [markdown]
# - 데이터 전처리

# %%
from tensorflow.keras.datasets import mnist
(X_train, y_train), (X_test, y_test) = mnist.load_data()
X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step
# 11501568/11490434 [==============================] - 0s 0us/step
# ((60000, 28, 28), (60000,), (10000, 28, 28), (10000,))

# %%
# X_train, X_test 정규화(0 ~ 1), 이미지 차원 변경: 2차원 --> 3차원
X_train = X_train.reshape(-1, 28, 28, 1) / 255.
X_test = X_test.reshape(-1, 28, 28, 1) / 255.
X_train.shape, X_test.shape
# Out:
# ((60000, 28, 28, 1), (10000, 28, 28, 1))

# %%
# One hot encoding
from tensorflow.keras.utils import to_categorical
Y_train = to_categorical(y_train)
Y_test = to_categorical(y_test)
Y_train.shape, Y_test.shape
# Out:
# ((60000, 10), (10000, 10))

# %% [markdown]
# - 모델 정의 / 설정 / 학습 / 평가

# %%
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Dense, Conv2D, Flatten, MaxPooling2D
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

# %%
model = Sequential([
    Conv2D(32, kernel_size=(3,3), input_shape=(28,28,1), activation='relu'),
    Conv2D(64, (3,3), activation='relu'),
    MaxPooling2D(),               # MaxPooling2D(pool_size=(2,2))
    Flatten(),
    Dense(512, activation='relu'),
    Dense(10, activation='softmax')
])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 26, 26, 32)        320
#
#  conv2d_1 (Conv2D)           (None, 24, 24, 64)        18496
#
#  max_pooling2d (MaxPooling2D  (None, 12, 12, 64)       0
#  )
#
#  flatten (Flatten)           (None, 9216)              0
#
#  dense (Dense)               (None, 512)               4719104
#
#  dense_1 (Dense)             (None, 10)                5130
#
# =================================================================
# Total params: 4,743,050
# Trainable params: 4,743,050
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile('adam', 'categorical_crossentropy', ['accuracy'])

# %%
model_path = 'best-mnist-cnn-v2.h5'
mc = ModelCheckpoint(model_path, save_best_only=True, verbose=1)
es = EarlyStopping(patience=10)

# %%
hist = model.fit(
    X_train, Y_train, validation_split=0.2, epochs=100, batch_size=200,
    callbacks=[mc, es]
)
# Out:
# Epoch 1/100
# 239/240 [============================>.] - ETA: 0s - loss: 0.1832 - accuracy: 0.9438
# Epoch 1: val_loss improved from inf to 0.06113, saving model to best-mnist-cnn-v2.h5
# 240/240 [==============================] - 14s 15ms/step - loss: 0.1828 - accuracy: 0.9439 - val_loss: 0.0611 - val_accuracy: 0.9812
# Epoch 2/100
# 240/240 [==============================] - ETA: 0s - loss: 0.0437 - accuracy: 0.9864
# Epoch 2: val_loss improved from 0.06113 to 0.05521, saving model to best-mnist-cnn-v2.h5
# 240/240 [==============================] - 4s 16ms/step - loss: 0.0437 - accuracy: 0.9864 - val_loss: 0.0552 - val_accuracy: 0.9850
# Epoch 3/100
# 240/240 [==============================] - ETA: 0s - loss: 0.0260 - accuracy: 0.9919
# Epoch 3: val_loss improved from 0.05521 to 0.03810, saving model to best-mnist-cnn-v2.h5
# 240/240 [==============================] - 3s 14ms/step - loss: 0.0260 - accuracy: 0.9919 - val_loss: 0.0381 - val_accuracy: 0.9895
# Epoch 4/100
# 237/240 [============================>.] - ETA: 0s - loss: 0.0170 - accuracy: 0.9945
# Epoch 4: val_loss did not improve from 0.03810
# 240/240 [==============================] - 3s 13ms/step - loss: 0.0170 - accuracy: 0.9945 - val_loss: 0.0450 - val_accuracy: 0.9868
# Epoch 5/100
# 239/240 [============================>.] - ETA: 0s - loss: 0.0113 - accuracy: 0.9963
# Epoch 5: val_loss did not improve from 0.03810
# 240/240 [==============================] - 3s 14ms/step - loss: 0.0113 - accuracy: 0.9963 - val_loss: 0.0501 - val_accuracy: 0.9875
# Epoch 6/100
# 238/240 [============================>.] - ETA: 0s - loss: 0.0095 - accuracy: 0.9968
# Epoch 6: val_loss did not improve from 0.03810
# 240/240 [==============================] - 3s 13ms/step - loss: 0.0095 - accuracy: 0.9968 - val_loss: 0.0423 - val_accuracy: 0.9899
# Epoch 7/100
# 240/240 [==============================] - ETA: 0s - loss: 0.0065 - accuracy: 0.9980
# Epoch 7: val_loss did not improve from 0.03810
# 240/240 [==============================] - 3s 13ms/step - loss: 0.0065 - accuracy: 0.9980 - val_loss: 0.0569 - val_accuracy: 0.9869
# Epoch 8/100
# 237/240 [============================>.] - ETA: 0s - loss: 0.0049 - accuracy: 0.9984
# Epoch 8: val_loss did not improve from 0.03810
# 240/240 [==============================] - 3s 13ms/step - loss: 0.0049 - accuracy: 0.9984 - val_loss: 0.0494 - val_accuracy: 0.9896
# Epoch 9/100
# 236/240 [============================>.] - ETA: 0s - loss: 0.0041 - accuracy: 0.9986
# Epoch 9: val_loss did not improve from 0.03810
# 240/240 [==============================] - 3s 13ms/step - loss: 0.0041 - accuracy: 0.9986 - val_loss: 0.0536 - val_accuracy: 0.9874
# Epoch 10/100
# 238/240 [============================>.] - ETA: 0s - loss: 0.0046 - accuracy: 0.9982
# Epoch 10: val_loss did not improve from 0.03810
# 240/240 [==============================] - 3s 13ms/step - loss: 0.0046 - accuracy: 0.9982 - val_loss: 0.0534 - val_accuracy: 0.9884
# Epoch 11/100
# 240/240 [==============================] - ETA: 0s - loss: 0.0028 - accuracy: 0.9992
# Epoch 11: val_loss did not improve from 0.03810
# 240/240 [==============================] - 3s 14ms/step - loss: 0.0028 - accuracy: 0.9992 - val_loss: 0.0567 - val_accuracy: 0.9889
# Epoch 12/100
# 238/240 [============================>.] - ETA: 0s - loss: 0.0045 - accuracy: 0.9985
# Epoch 12: val_loss did not improve from 0.03810
# 240/240 [==============================] - 3s 14ms/step - loss: 0.0046 - accuracy: 0.9985 - val_loss: 0.0577 - val_accuracy: 0.9887
# Epoch 13/100
# 236/240 [============================>.] - ETA: 0s - loss: 0.0031 - accuracy: 0.9990
# Epoch 13: val_loss did not improve from 0.03810
# 240/240 [==============================] - 3s 13ms/step - loss: 0.0033 - accuracy: 0.9990 - val_loss: 0.0610 - val_accuracy: 0.9877

# %%
best_model = load_model(model_path)
best_model.evaluate(X_test, Y_test)
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0360 - accuracy: 0.9888
# [0.03598953038454056, 0.9887999892234802]

# %% [markdown]
# - 학습과정 시각화

# %%
y_acc = hist.history['accuracy']
y_vloss = hist.history['val_loss']
xs = np.arange(1, len(y_acc)+1)

# %%
plt.figure(figsize=(12,8))
plt.plot(xs, y_acc, label='train accuracy')
plt.plot(xs, y_vloss, label='validation loss')
plt.legend(), plt.grid(), plt.ylim([0,1.2])
plt.xlabel('Epoch')
plt.title('MNIST CNN model v1')
plt.show()
