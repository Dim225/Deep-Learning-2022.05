# %% [markdown]
# # MNIST 손글씨 - CNN v3
# - 2 x Conv2D layers
# - MaxPooling 2D layer
# - Dropout(0.25) layer
# - 1 FCN layer
# - 1 Output layer

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
seed = 2022
np.random.seed(seed)
tf.random.set_seed(seed)

# %% [markdown]
# - 데이터 전처리

# %%
from tensorflow.keras.datasets import mnist
(X_train, y_train), (X_test, y_test) = mnist.load_data()
X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step
# 11501568/11490434 [==============================] - 0s 0us/step
# ((60000, 28, 28), (60000,), (10000, 28, 28), (10000,))

# %%
# X_train, X_test 정규화(0 ~ 1), 이미지 차원 변경: 2차원 --> 3차원
X_train = X_train.reshape(-1, 28, 28, 1) / 255.
X_test = X_test.reshape(-1, 28, 28, 1) / 255.
X_train.shape, X_test.shape
# Out:
# ((60000, 28, 28, 1), (10000, 28, 28, 1))

# %%
# One hot encoding
from tensorflow.keras.utils import to_categorical
Y_train = to_categorical(y_train)
Y_test = to_categorical(y_test)
Y_train.shape, Y_test.shape
# Out:
# ((60000, 10), (10000, 10))

# %% [markdown]
# - 모델 정의 / 설정 / 학습 / 평가

# %%
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Dense, Conv2D, Flatten, MaxPooling2D, Dropout
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

# %%
model = Sequential([
    Conv2D(32, kernel_size=(3,3), input_shape=(28,28,1), activation='relu'),
    Conv2D(64, (3,3), activation='relu'),
    MaxPooling2D(),               # MaxPooling2D(pool_size=(2,2))
    Dropout(0.25),
    Flatten(),
    Dense(512, activation='relu'),
    Dropout(0.5),
    Dense(10, activation='softmax')
])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 26, 26, 32)        320
#
#  conv2d_1 (Conv2D)           (None, 24, 24, 64)        18496
#
#  max_pooling2d (MaxPooling2D  (None, 12, 12, 64)       0
#  )
#
#  dropout (Dropout)           (None, 12, 12, 64)        0
#
#  flatten (Flatten)           (None, 9216)              0
#
#  dense (Dense)               (None, 512)               4719104
#
#  dropout_1 (Dropout)         (None, 512)               0
#
#  dense_1 (Dense)             (None, 10)                5130
#
# =================================================================
# Total params: 4,743,050
# Trainable params: 4,743,050
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile('adam', 'categorical_crossentropy', ['accuracy'])

# %%
model_path = 'best-mnist-cnn-v2.h5'
mc = ModelCheckpoint(model_path, save_best_only=True, verbose=1)
es = EarlyStopping(patience=10)

# %%
hist = model.fit(
    X_train, Y_train, validation_split=0.2, epochs=100, batch_size=200,
    callbacks=[mc, es]
)
# Out:
# Epoch 1/100
# 237/240 [============================>.] - ETA: 0s - loss: 0.2221 - accuracy: 0.9314
# Epoch 1: val_loss improved from inf to 0.05655, saving model to best-mnist-cnn-v2.h5
# 240/240 [==============================] - 15s 17ms/step - loss: 0.2204 - accuracy: 0.9319 - val_loss: 0.0566 - val_accuracy: 0.9833
# Epoch 2/100
# 237/240 [============================>.] - ETA: 0s - loss: 0.0625 - accuracy: 0.9809
# Epoch 2: val_loss improved from 0.05655 to 0.05152, saving model to best-mnist-cnn-v2.h5
# 240/240 [==============================] - 4s 15ms/step - loss: 0.0623 - accuracy: 0.9810 - val_loss: 0.0515 - val_accuracy: 0.9848
# Epoch 3/100
# 236/240 [============================>.] - ETA: 0s - loss: 0.0434 - accuracy: 0.9866
# Epoch 3: val_loss improved from 0.05152 to 0.03926, saving model to best-mnist-cnn-v2.h5
# 240/240 [==============================] - 3s 14ms/step - loss: 0.0433 - accuracy: 0.9866 - val_loss: 0.0393 - val_accuracy: 0.9884
# Epoch 4/100
# 236/240 [============================>.] - ETA: 0s - loss: 0.0339 - accuracy: 0.9896
# Epoch 4: val_loss improved from 0.03926 to 0.03770, saving model to best-mnist-cnn-v2.h5
# 240/240 [==============================] - 3s 14ms/step - loss: 0.0340 - accuracy: 0.9896 - val_loss: 0.0377 - val_accuracy: 0.9893
# Epoch 5/100
# 239/240 [============================>.] - ETA: 0s - loss: 0.0284 - accuracy: 0.9909
# Epoch 5: val_loss improved from 0.03770 to 0.03666, saving model to best-mnist-cnn-v2.h5
# 240/240 [==============================] - 3s 14ms/step - loss: 0.0284 - accuracy: 0.9909 - val_loss: 0.0367 - val_accuracy: 0.9897
# Epoch 6/100
# 240/240 [==============================] - ETA: 0s - loss: 0.0225 - accuracy: 0.9925
# Epoch 6: val_loss improved from 0.03666 to 0.03355, saving model to best-mnist-cnn-v2.h5
# 240/240 [==============================] - 3s 14ms/step - loss: 0.0225 - accuracy: 0.9925 - val_loss: 0.0335 - val_accuracy: 0.9901
# Epoch 7/100
# 238/240 [============================>.] - ETA: 0s - loss: 0.0187 - accuracy: 0.9941
# Epoch 7: val_loss did not improve from 0.03355
# 240/240 [==============================] - 3s 13ms/step - loss: 0.0186 - accuracy: 0.9941 - val_loss: 0.0347 - val_accuracy: 0.9908
# Epoch 8/100
# 236/240 [============================>.] - ETA: 0s - loss: 0.0161 - accuracy: 0.9943
# Epoch 8: val_loss did not improve from 0.03355
# 240/240 [==============================] - 3s 13ms/step - loss: 0.0165 - accuracy: 0.9941 - val_loss: 0.0350 - val_accuracy: 0.9906
# Epoch 9/100
# 240/240 [==============================] - ETA: 0s - loss: 0.0161 - accuracy: 0.9945
# Epoch 9: val_loss did not improve from 0.03355
# 240/240 [==============================] - 3s 13ms/step - loss: 0.0161 - accuracy: 0.9945 - val_loss: 0.0351 - val_accuracy: 0.9908
# Epoch 10/100
# 240/240 [==============================] - ETA: 0s - loss: 0.0133 - accuracy: 0.9956
# Epoch 10: val_loss improved from 0.03355 to 0.03322, saving model to best-mnist-cnn-v2.h5
# 240/240 [==============================] - 3s 14ms/step - loss: 0.0133 - accuracy: 0.9956 - val_loss: 0.0332 - val_accuracy: 0.9918
# Epoch 11/100
# 239/240 [============================>.] - ETA: 0s - loss: 0.0122 - accuracy: 0.9957
# Epoch 11: val_loss did not improve from 0.03322
# 240/240 [==============================] - 3s 13ms/step - loss: 0.0122 - accuracy: 0.9957 - val_loss: 0.0389 - val_accuracy: 0.9905
# Epoch 12/100
# 239/240 [============================>.] - ETA: 0s - loss: 0.0115 - accuracy: 0.9962
# Epoch 12: val_loss did not improve from 0.03322
# 240/240 [==============================] - 3s 13ms/step - loss: 0.0114 - accuracy: 0.9962 - val_loss: 0.0365 - val_accuracy: 0.9917
# Epoch 13/100
# 236/240 [============================>.] - ETA: 0s - loss: 0.0106 - accuracy: 0.9968
# Epoch 13: val_loss did not improve from 0.03322
# 240/240 [==============================] - 3s 13ms/step - loss: 0.0107 - accuracy: 0.9967 - val_loss: 0.0357 - val_accuracy: 0.9910
# Epoch 14/100
# 237/240 [============================>.] - ETA: 0s - loss: 0.0099 - accuracy: 0.9966
# Epoch 14: val_loss did not improve from 0.03322
# 240/240 [==============================] - 3s 13ms/step - loss: 0.0099 - accuracy: 0.9966 - val_loss: 0.0374 - val_accuracy: 0.9911
# Epoch 15/100
# 238/240 [============================>.] - ETA: 0s - loss: 0.0087 - accuracy: 0.9971
# Epoch 15: val_loss did not improve from 0.03322
# 240/240 [==============================] - 3s 13ms/step - loss: 0.0087 - accuracy: 0.9971 - val_loss: 0.0352 - val_accuracy: 0.9908
# Epoch 16/100
# 237/240 [============================>.] - ETA: 0s - loss: 0.0079 - accuracy: 0.9975
# Epoch 16: val_loss did not improve from 0.03322
# 240/240 [==============================] - 3s 13ms/step - loss: 0.0079 - accuracy: 0.9975 - val_loss: 0.0404 - val_accuracy: 0.9909
# Epoch 17/100
# 236/240 [============================>.] - ETA: 0s - loss: 0.0086 - accuracy: 0.9972
# Epoch 17: val_loss did not improve from 0.03322
# 240/240 [==============================] - 3s 13ms/step - loss: 0.0086 - accuracy: 0.9971 - val_loss: 0.0380 - val_accuracy: 0.9923
# Epoch 18/100
# 239/240 [============================>.] - ETA: 0s - loss: 0.0070 - accuracy: 0.9978
# Epoch 18: val_loss did not improve from 0.03322
# 240/240 [==============================] - 3s 13ms/step - loss: 0.0070 - accuracy: 0.9978 - val_loss: 0.0394 - val_accuracy: 0.9902
# Epoch 19/100
# 237/240 [============================>.] - ETA: 0s - loss: 0.0069 - accuracy: 0.9976
# Epoch 19: val_loss did not improve from 0.03322
# 240/240 [==============================] - 3s 13ms/step - loss: 0.0070 - accuracy: 0.9976 - val_loss: 0.0371 - val_accuracy: 0.9917
# Epoch 20/100
# 236/240 [============================>.] - ETA: 0s - loss: 0.0070 - accuracy: 0.9975
# Epoch 20: val_loss did not improve from 0.03322
# 240/240 [==============================] - 3s 13ms/step - loss: 0.0071 - accuracy: 0.9975 - val_loss: 0.0399 - val_accuracy: 0.9913

# %%
best_model = load_model(model_path)
best_model.evaluate(X_test, Y_test)
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0295 - accuracy: 0.9913
# [0.0295428317040205, 0.9912999868392944]

# %% [markdown]
# - 학습과정 시각화

# %%
y_acc = hist.history['accuracy']
y_vloss = hist.history['val_loss']
xs = np.arange(1, len(y_acc)+1)

# %%
plt.figure(figsize=(12,8))
plt.plot(xs, y_acc, label='train accuracy')
plt.plot(xs, y_vloss, label='validation loss')
plt.legend(), plt.grid(), plt.ylim([0,1.2])
plt.xlabel('Epoch')
plt.title('MNIST CNN model v1')
plt.show()
