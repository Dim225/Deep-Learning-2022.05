# %% [markdown]
# # 신경망 모델에서 옵티마이저 사용법
# - 이진분류: 유방암 예측 사례

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import load_breast_cancer
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %%
cancer = load_breast_cancer()
cancer_std = StandardScaler().fit_transform(cancer.data)
X_train, X_test, y_train, y_test = train_test_split(
    cancer_std, cancer.target, stratify=cancer.target,
    test_size=0.2, random_state=2022
)

# %% [markdown]
# ## 1. Adam optimizer

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
model = Sequential([
    Dense(100, input_dim=30, activation='relu'),
    Dense(24, activation='relu'),
    Dense(1, activation='sigmoid')
])

# %% [markdown]
# ### Adam 하이퍼 파라메터
# - learning_rate: 0보다 크거나 같은 float 값. 학습률.
# - beta_1: 0보다 크고 1보다 작은 float 값. 일반적으로 1에 가깝게 설정됩니다.
# - beta_2: 0보다 크고 1보다 작은 float 값. 일반적으로 1에 가깝게 설정됩니다.
# - epsilon: 0보다 크거나 같은 float형 fuzz factor. None인 경우 K.epsilon()이 사용됩니다.
# - decay: 0보다 크거나 같은 float 값. 업데이트마다 적용되는 학습률의 감소율입니다.
# - amsgrad: 불리언. Adam의 변형인 AMSGrad의 적용 여부를 설정합니다

# %%
from tensorflow.keras.optimizers import Adam
adam = Adam(learning_rate=0.001, beta_1=0.9, beta_2=0.999,
            epsilon=None, decay=0.0, amsgrad=False)

# %%
model.compile(optimizer=adam, loss='binary_crossentropy', metrics=['accuracy'])

# %%
hist = model.fit(X_train, y_train, validation_split=0.2,
                 epochs=100, batch_size=100, verbose=0)

# %%
model.evaluate(X_test, y_test)
# Out:
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0639 - accuracy: 0.9737
# [0.06386880576610565, 0.9736841917037964]

# %%
y_acc = hist.history['accuracy']
y_vloss = hist.history['val_loss']
xs = np.arange(1,len(y_acc)+1)

# %%
plt.figure(figsize=(12,8))
plt.plot(xs, y_acc, label='train accuracy')
plt.plot(xs, y_vloss, label='validation loss')
plt.legend()
plt.grid()
plt.ylim([0,1.1])
plt.xlabel('Epoch')
plt.title('Adam optimizer')
plt.show()

# %% [markdown]
# ## 2. RMSprop Optimizer

# %%
model2 = Sequential([
    Dense(100, input_dim=30, activation='relu'),
    Dense(24, activation='relu'),
    Dense(1, activation='sigmoid')
])

# %% [markdown]
# ### RMSprop 하이퍼 파라메터
# - lr: 0보다 크거나 같은 float 값. 학습률.
# - rho: 0보다 크거나 같은 float 값.
# - epsilon: 0보다 크거나 같은 float형 fuzz factor. None인 경우 K.epsilon()이 사용됩니다.
# - decay: 0보다 크거나 같은 float 값. 업데이트마다 적용되는 학습률의 감소율입니다.

# %%
from tensorflow.keras.optimizers import RMSprop
rmsp = RMSprop(learning_rate=0.001, rho=0.9, epsilon=None, decay=0.0)

# %%
model2.compile(rmsp, 'binary_crossentropy', ['accuracy'])

# %%
hist2 = model2.fit(X_train, y_train, validation_split=0.2,
                   epochs=100, batch_size=100, verbose=2)
# Out:
# Epoch 1/100
# 4/4 - 1s - loss: 0.5506 - accuracy: 0.7747 - val_loss: 0.3991 - val_accuracy: 0.8791 - 1s/epoch - 325ms/step
# Epoch 2/100
# 4/4 - 0s - loss: 0.3445 - accuracy: 0.8984 - val_loss: 0.3087 - val_accuracy: 0.9121 - 49ms/epoch - 12ms/step
# Epoch 3/100
# 4/4 - 0s - loss: 0.2661 - accuracy: 0.9203 - val_loss: 0.2580 - val_accuracy: 0.9231 - 61ms/epoch - 15ms/step
# Epoch 4/100
# 4/4 - 0s - loss: 0.2207 - accuracy: 0.9341 - val_loss: 0.2260 - val_accuracy: 0.9451 - 49ms/epoch - 12ms/step
# Epoch 5/100
# 4/4 - 0s - loss: 0.1889 - accuracy: 0.9560 - val_loss: 0.2009 - val_accuracy: 0.9451 - 53ms/epoch - 13ms/step
# Epoch 6/100
# 4/4 - 0s - loss: 0.1653 - accuracy: 0.9588 - val_loss: 0.1829 - val_accuracy: 0.9670 - 59ms/epoch - 15ms/step
# Epoch 7/100
# 4/4 - 0s - loss: 0.1464 - accuracy: 0.9670 - val_loss: 0.1690 - val_accuracy: 0.9560 - 58ms/epoch - 14ms/step
# Epoch 8/100
# 4/4 - 0s - loss: 0.1306 - accuracy: 0.9698 - val_loss: 0.1574 - val_accuracy: 0.9560 - 50ms/epoch - 13ms/step
# Epoch 9/100
# 4/4 - 0s - loss: 0.1182 - accuracy: 0.9753 - val_loss: 0.1503 - val_accuracy: 0.9560 - 69ms/epoch - 17ms/step
# Epoch 10/100
# 4/4 - 0s - loss: 0.1069 - accuracy: 0.9780 - val_loss: 0.1416 - val_accuracy: 0.9560 - 54ms/epoch - 14ms/step
# Epoch 11/100
# 4/4 - 0s - loss: 0.0975 - accuracy: 0.9753 - val_loss: 0.1360 - val_accuracy: 0.9560 - 56ms/epoch - 14ms/step
# Epoch 12/100
# 4/4 - 0s - loss: 0.0903 - accuracy: 0.9753 - val_loss: 0.1297 - val_accuracy: 0.9560 - 55ms/epoch - 14ms/step
# Epoch 13/100
# 4/4 - 0s - loss: 0.0842 - accuracy: 0.9808 - val_loss: 0.1269 - val_accuracy: 0.9560 - 75ms/epoch - 19ms/step
# Epoch 14/100
# 4/4 - 0s - loss: 0.0786 - accuracy: 0.9780 - val_loss: 0.1232 - val_accuracy: 0.9560 - 59ms/epoch - 15ms/step
# Epoch 15/100
# 4/4 - 0s - loss: 0.0736 - accuracy: 0.9780 - val_loss: 0.1208 - val_accuracy: 0.9560 - 37ms/epoch - 9ms/step
# Epoch 16/100
# 4/4 - 0s - loss: 0.0691 - accuracy: 0.9808 - val_loss: 0.1196 - val_accuracy: 0.9560 - 32ms/epoch - 8ms/step
# Epoch 17/100
# 4/4 - 0s - loss: 0.0651 - accuracy: 0.9835 - val_loss: 0.1191 - val_accuracy: 0.9560 - 38ms/epoch - 10ms/step
# Epoch 18/100
# 4/4 - 0s - loss: 0.0621 - accuracy: 0.9835 - val_loss: 0.1176 - val_accuracy: 0.9560 - 34ms/epoch - 9ms/step
# Epoch 19/100
# 4/4 - 0s - loss: 0.0582 - accuracy: 0.9835 - val_loss: 0.1159 - val_accuracy: 0.9560 - 42ms/epoch - 10ms/step
# Epoch 20/100
# 4/4 - 0s - loss: 0.0556 - accuracy: 0.9863 - val_loss: 0.1165 - val_accuracy: 0.9560 - 39ms/epoch - 10ms/step
# Epoch 21/100
# 4/4 - 0s - loss: 0.0528 - accuracy: 0.9835 - val_loss: 0.1157 - val_accuracy: 0.9560 - 37ms/epoch - 9ms/step
# Epoch 22/100
# 4/4 - 0s - loss: 0.0500 - accuracy: 0.9863 - val_loss: 0.1147 - val_accuracy: 0.9560 - 36ms/epoch - 9ms/step
# Epoch 23/100
# 4/4 - 0s - loss: 0.0479 - accuracy: 0.9835 - val_loss: 0.1160 - val_accuracy: 0.9560 - 37ms/epoch - 9ms/step
# Epoch 24/100
# 4/4 - 0s - loss: 0.0458 - accuracy: 0.9835 - val_loss: 0.1169 - val_accuracy: 0.9560 - 38ms/epoch - 9ms/step
# Epoch 25/100
# 4/4 - 0s - loss: 0.0440 - accuracy: 0.9863 - val_loss: 0.1174 - val_accuracy: 0.9560 - 42ms/epoch - 10ms/step
# Epoch 26/100
# 4/4 - 0s - loss: 0.0411 - accuracy: 0.9863 - val_loss: 0.1182 - val_accuracy: 0.9560 - 37ms/epoch - 9ms/step
# Epoch 27/100
# 4/4 - 0s - loss: 0.0390 - accuracy: 0.9863 - val_loss: 0.1198 - val_accuracy: 0.9560 - 40ms/epoch - 10ms/step
# Epoch 28/100
# 4/4 - 0s - loss: 0.0369 - accuracy: 0.9863 - val_loss: 0.1212 - val_accuracy: 0.9560 - 44ms/epoch - 11ms/step
# Epoch 29/100
# 4/4 - 0s - loss: 0.0352 - accuracy: 0.9863 - val_loss: 0.1221 - val_accuracy: 0.9560 - 47ms/epoch - 12ms/step
# Epoch 30/100
# 4/4 - 0s - loss: 0.0338 - accuracy: 0.9890 - val_loss: 0.1247 - val_accuracy: 0.9560 - 34ms/epoch - 9ms/step
# Epoch 31/100
# 4/4 - 0s - loss: 0.0312 - accuracy: 0.9863 - val_loss: 0.1240 - val_accuracy: 0.9560 - 37ms/epoch - 9ms/step
# Epoch 32/100
# 4/4 - 0s - loss: 0.0295 - accuracy: 0.9890 - val_loss: 0.1264 - val_accuracy: 0.9560 - 36ms/epoch - 9ms/step
# Epoch 33/100
# 4/4 - 0s - loss: 0.0278 - accuracy: 0.9890 - val_loss: 0.1287 - val_accuracy: 0.9560 - 38ms/epoch - 10ms/step
# Epoch 34/100
# 4/4 - 0s - loss: 0.0258 - accuracy: 0.9890 - val_loss: 0.1310 - val_accuracy: 0.9560 - 36ms/epoch - 9ms/step
# Epoch 35/100
# 4/4 - 0s - loss: 0.0245 - accuracy: 0.9890 - val_loss: 0.1281 - val_accuracy: 0.9560 - 39ms/epoch - 10ms/step
# Epoch 36/100
# 4/4 - 0s - loss: 0.0224 - accuracy: 0.9890 - val_loss: 0.1307 - val_accuracy: 0.9670 - 41ms/epoch - 10ms/step
# Epoch 37/100
# 4/4 - 0s - loss: 0.0210 - accuracy: 0.9918 - val_loss: 0.1320 - val_accuracy: 0.9670 - 34ms/epoch - 9ms/step
# Epoch 38/100
# 4/4 - 0s - loss: 0.0200 - accuracy: 0.9918 - val_loss: 0.1373 - val_accuracy: 0.9670 - 38ms/epoch - 10ms/step
# Epoch 39/100
# 4/4 - 0s - loss: 0.0190 - accuracy: 0.9918 - val_loss: 0.1331 - val_accuracy: 0.9670 - 36ms/epoch - 9ms/step
# Epoch 40/100
# 4/4 - 0s - loss: 0.0169 - accuracy: 1.0000 - val_loss: 0.1359 - val_accuracy: 0.9670 - 35ms/epoch - 9ms/step
# Epoch 41/100
# 4/4 - 0s - loss: 0.0157 - accuracy: 0.9973 - val_loss: 0.1355 - val_accuracy: 0.9670 - 32ms/epoch - 8ms/step
# Epoch 42/100
# 4/4 - 0s - loss: 0.0150 - accuracy: 1.0000 - val_loss: 0.1396 - val_accuracy: 0.9670 - 31ms/epoch - 8ms/step
# Epoch 43/100
# 4/4 - 0s - loss: 0.0136 - accuracy: 1.0000 - val_loss: 0.1416 - val_accuracy: 0.9670 - 33ms/epoch - 8ms/step
# Epoch 44/100
# 4/4 - 0s - loss: 0.0126 - accuracy: 1.0000 - val_loss: 0.1482 - val_accuracy: 0.9560 - 33ms/epoch - 8ms/step
# Epoch 45/100
# 4/4 - 0s - loss: 0.0114 - accuracy: 1.0000 - val_loss: 0.1437 - val_accuracy: 0.9670 - 32ms/epoch - 8ms/step
# Epoch 46/100
# 4/4 - 0s - loss: 0.0110 - accuracy: 1.0000 - val_loss: 0.1523 - val_accuracy: 0.9670 - 39ms/epoch - 10ms/step
# Epoch 47/100
# 4/4 - 0s - loss: 0.0104 - accuracy: 1.0000 - val_loss: 0.1573 - val_accuracy: 0.9670 - 34ms/epoch - 8ms/step
# Epoch 48/100
# 4/4 - 0s - loss: 0.0090 - accuracy: 1.0000 - val_loss: 0.1561 - val_accuracy: 0.9670 - 31ms/epoch - 8ms/step
# Epoch 49/100
# 4/4 - 0s - loss: 0.0084 - accuracy: 1.0000 - val_loss: 0.1578 - val_accuracy: 0.9560 - 33ms/epoch - 8ms/step
# Epoch 50/100
# 4/4 - 0s - loss: 0.0075 - accuracy: 1.0000 - val_loss: 0.1547 - val_accuracy: 0.9670 - 31ms/epoch - 8ms/step
# Epoch 51/100
# 4/4 - 0s - loss: 0.0070 - accuracy: 1.0000 - val_loss: 0.1664 - val_accuracy: 0.9560 - 30ms/epoch - 8ms/step
# Epoch 52/100
# 4/4 - 0s - loss: 0.0064 - accuracy: 1.0000 - val_loss: 0.1631 - val_accuracy: 0.9560 - 32ms/epoch - 8ms/step
# Epoch 53/100
# 4/4 - 0s - loss: 0.0057 - accuracy: 1.0000 - val_loss: 0.1615 - val_accuracy: 0.9560 - 30ms/epoch - 7ms/step
# Epoch 54/100
# 4/4 - 0s - loss: 0.0054 - accuracy: 1.0000 - val_loss: 0.1673 - val_accuracy: 0.9560 - 38ms/epoch - 10ms/step
# Epoch 55/100
# 4/4 - 0s - loss: 0.0053 - accuracy: 1.0000 - val_loss: 0.1728 - val_accuracy: 0.9560 - 53ms/epoch - 13ms/step
# Epoch 56/100
# 4/4 - 0s - loss: 0.0049 - accuracy: 1.0000 - val_loss: 0.1621 - val_accuracy: 0.9560 - 32ms/epoch - 8ms/step
# Epoch 57/100
# 4/4 - 0s - loss: 0.0042 - accuracy: 1.0000 - val_loss: 0.1620 - val_accuracy: 0.9560 - 34ms/epoch - 9ms/step
# Epoch 58/100
# 4/4 - 0s - loss: 0.0040 - accuracy: 1.0000 - val_loss: 0.1664 - val_accuracy: 0.9560 - 37ms/epoch - 9ms/step
# Epoch 59/100
# 4/4 - 0s - loss: 0.0036 - accuracy: 1.0000 - val_loss: 0.1646 - val_accuracy: 0.9560 - 34ms/epoch - 8ms/step
# Epoch 60/100
# 4/4 - 0s - loss: 0.0032 - accuracy: 1.0000 - val_loss: 0.1575 - val_accuracy: 0.9560 - 36ms/epoch - 9ms/step
# Epoch 61/100
# 4/4 - 0s - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.1631 - val_accuracy: 0.9560 - 34ms/epoch - 8ms/step
# Epoch 62/100
# 4/4 - 0s - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.1703 - val_accuracy: 0.9560 - 33ms/epoch - 8ms/step
# Epoch 63/100
# 4/4 - 0s - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.1630 - val_accuracy: 0.9560 - 35ms/epoch - 9ms/step
# Epoch 64/100
# 4/4 - 0s - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.1639 - val_accuracy: 0.9560 - 34ms/epoch - 8ms/step
# Epoch 65/100
# 4/4 - 0s - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.1657 - val_accuracy: 0.9560 - 35ms/epoch - 9ms/step
# Epoch 66/100
# 4/4 - 0s - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.1624 - val_accuracy: 0.9560 - 36ms/epoch - 9ms/step
# Epoch 67/100
# 4/4 - 0s - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.1634 - val_accuracy: 0.9560 - 39ms/epoch - 10ms/step
# Epoch 68/100
# 4/4 - 0s - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.1676 - val_accuracy: 0.9560 - 32ms/epoch - 8ms/step
# Epoch 69/100
# 4/4 - 0s - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.1755 - val_accuracy: 0.9560 - 38ms/epoch - 9ms/step
# Epoch 70/100
# 4/4 - 0s - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1611 - val_accuracy: 0.9560 - 32ms/epoch - 8ms/step
# Epoch 71/100
# 4/4 - 0s - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1737 - val_accuracy: 0.9560 - 32ms/epoch - 8ms/step
# Epoch 72/100
# 4/4 - 0s - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1715 - val_accuracy: 0.9560 - 35ms/epoch - 9ms/step
# Epoch 73/100
# 4/4 - 0s - loss: 8.4701e-04 - accuracy: 1.0000 - val_loss: 0.1636 - val_accuracy: 0.9560 - 28ms/epoch - 7ms/step
# Epoch 74/100
# 4/4 - 0s - loss: 8.4424e-04 - accuracy: 1.0000 - val_loss: 0.1631 - val_accuracy: 0.9560 - 30ms/epoch - 8ms/step
# Epoch 75/100
# 4/4 - 0s - loss: 7.1807e-04 - accuracy: 1.0000 - val_loss: 0.1683 - val_accuracy: 0.9560 - 32ms/epoch - 8ms/step
# Epoch 76/100
# 4/4 - 0s - loss: 7.0570e-04 - accuracy: 1.0000 - val_loss: 0.1675 - val_accuracy: 0.9560 - 32ms/epoch - 8ms/step
# Epoch 77/100
# 4/4 - 0s - loss: 5.6686e-04 - accuracy: 1.0000 - val_loss: 0.1648 - val_accuracy: 0.9560 - 32ms/epoch - 8ms/step
# Epoch 78/100
# 4/4 - 0s - loss: 5.1562e-04 - accuracy: 1.0000 - val_loss: 0.1576 - val_accuracy: 0.9560 - 35ms/epoch - 9ms/step
# Epoch 79/100
# 4/4 - 0s - loss: 5.0363e-04 - accuracy: 1.0000 - val_loss: 0.1656 - val_accuracy: 0.9560 - 36ms/epoch - 9ms/step
# Epoch 80/100
# 4/4 - 0s - loss: 4.0067e-04 - accuracy: 1.0000 - val_loss: 0.1689 - val_accuracy: 0.9560 - 31ms/epoch - 8ms/step
# Epoch 81/100
# 4/4 - 0s - loss: 3.8967e-04 - accuracy: 1.0000 - val_loss: 0.1614 - val_accuracy: 0.9560 - 43ms/epoch - 11ms/step
# Epoch 82/100
# 4/4 - 0s - loss: 3.5946e-04 - accuracy: 1.0000 - val_loss: 0.1657 - val_accuracy: 0.9560 - 31ms/epoch - 8ms/step
# Epoch 83/100
# 4/4 - 0s - loss: 3.1228e-04 - accuracy: 1.0000 - val_loss: 0.1720 - val_accuracy: 0.9560 - 29ms/epoch - 7ms/step
# Epoch 84/100
# 4/4 - 0s - loss: 2.5025e-04 - accuracy: 1.0000 - val_loss: 0.1601 - val_accuracy: 0.9560 - 33ms/epoch - 8ms/step
# Epoch 85/100
# 4/4 - 0s - loss: 2.2718e-04 - accuracy: 1.0000 - val_loss: 0.1609 - val_accuracy: 0.9560 - 37ms/epoch - 9ms/step
# Epoch 86/100
# 4/4 - 0s - loss: 2.1758e-04 - accuracy: 1.0000 - val_loss: 0.1576 - val_accuracy: 0.9560 - 35ms/epoch - 9ms/step
# Epoch 87/100
# 4/4 - 0s - loss: 2.1187e-04 - accuracy: 1.0000 - val_loss: 0.1747 - val_accuracy: 0.9560 - 31ms/epoch - 8ms/step
# Epoch 88/100
# 4/4 - 0s - loss: 2.0574e-04 - accuracy: 1.0000 - val_loss: 0.1606 - val_accuracy: 0.9560 - 40ms/epoch - 10ms/step
# Epoch 89/100
# 4/4 - 0s - loss: 1.3918e-04 - accuracy: 1.0000 - val_loss: 0.1639 - val_accuracy: 0.9560 - 34ms/epoch - 9ms/step
# Epoch 90/100
# 4/4 - 0s - loss: 1.2614e-04 - accuracy: 1.0000 - val_loss: 0.1617 - val_accuracy: 0.9560 - 41ms/epoch - 10ms/step
# Epoch 91/100
# 4/4 - 0s - loss: 1.1130e-04 - accuracy: 1.0000 - val_loss: 0.1659 - val_accuracy: 0.9560 - 34ms/epoch - 9ms/step
# Epoch 92/100
# 4/4 - 0s - loss: 1.1088e-04 - accuracy: 1.0000 - val_loss: 0.1740 - val_accuracy: 0.9560 - 43ms/epoch - 11ms/step
# Epoch 93/100
# 4/4 - 0s - loss: 9.2765e-05 - accuracy: 1.0000 - val_loss: 0.1530 - val_accuracy: 0.9670 - 39ms/epoch - 10ms/step
# Epoch 94/100
# 4/4 - 0s - loss: 1.0813e-04 - accuracy: 1.0000 - val_loss: 0.1631 - val_accuracy: 0.9560 - 36ms/epoch - 9ms/step
# Epoch 95/100
# 4/4 - 0s - loss: 7.8893e-05 - accuracy: 1.0000 - val_loss: 0.1565 - val_accuracy: 0.9670 - 37ms/epoch - 9ms/step
# Epoch 96/100
# 4/4 - 0s - loss: 7.2041e-05 - accuracy: 1.0000 - val_loss: 0.1607 - val_accuracy: 0.9670 - 38ms/epoch - 9ms/step
# Epoch 97/100
# 4/4 - 0s - loss: 5.8948e-05 - accuracy: 1.0000 - val_loss: 0.1521 - val_accuracy: 0.9560 - 38ms/epoch - 9ms/step
# Epoch 98/100
# 4/4 - 0s - loss: 4.8881e-05 - accuracy: 1.0000 - val_loss: 0.1613 - val_accuracy: 0.9670 - 38ms/epoch - 9ms/step
# Epoch 99/100
# 4/4 - 0s - loss: 4.9834e-05 - accuracy: 1.0000 - val_loss: 0.1635 - val_accuracy: 0.9670 - 36ms/epoch - 9ms/step
# Epoch 100/100
# 4/4 - 0s - loss: 4.6237e-05 - accuracy: 1.0000 - val_loss: 0.1656 - val_accuracy: 0.9670 - 36ms/epoch - 9ms/step

# %%
model2.evaluate(X_test, y_test)
# Out:
# 4/4 [==============================] - 0s 9ms/step - loss: 0.1400 - accuracy: 0.9825
# [0.14002478122711182, 0.9824561476707458]

# %%
y_acc2 = hist2.history['accuracy']
y_vloss2 = hist2.history['val_loss']
xs = np.arange(1,len(y_acc2)+1)

# %%
plt.figure(figsize=(20,8))
plt.subplot(121)
plt.plot(xs, y_acc, label='train accuracy')
plt.plot(xs, y_vloss, label='validation loss')
plt.legend()
plt.grid()
plt.ylim([0,1.1])
plt.xlabel('Epoch')
plt.title('Adam optimizer')

plt.subplot(122)
plt.plot(xs, y_acc2, label='train accuracy')
plt.plot(xs, y_vloss2, label='validation loss')
plt.legend()
plt.grid()
plt.ylim([0,1.1])
plt.xlabel('Epoch')
plt.title('RMSprop optimizer')
plt.show()
